# %%
import pandas as pd
from autogluon.tabular import TabularPredictor
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np
import torch
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
print(torch.cuda.is_available())  # GPU 사용 가능 여부 (True/False)
print(torch.cuda.device_count())  # 사용 가능한 GPU 개수
print(torch.cuda.get_device_name(0))  # 첫 번째 GPU의 이름 출력 (GPU가 있을 경우)

#########################################

#########################################
def preprocess_data(df):

    # 제거할 컬럼
    drop_columns = [
        '불임 원인 - 자궁경부 문제', '불임 원인 - 정자 면역학적 요인',
        '불임 원인 - 정자 운동성', '시술 유형', 'DI 출산 횟수', '정자 출처', '부부 부 불임 원인', '여성 부 불임 원인', '불임 원인 - 정자 형태', '대리모 여부', '불임 원인 - 정자 농도',
        '착상 전 유전 진단 사용 여부', '기증 배아 사용 여부'
    ]

    df = df.drop(columns=[col for col in drop_columns if col in df.columns])

    # ✅ 피처 엔지니어링 적용
    df["배아 수 제곱"] = df["이식된 배아 수"] ** 2

    # ✅ 연령대를 중앙값으로 변환하여 숫자로 변환
    age_mapping = {
        "만18-34세": 26,
        "만35-37세": 36,
        "만38-39세": 38.5,
        "만40-42세": 41,
        "만43-44세": 43.5,
        "만45-50세": 47.5,
        "알 수 없음": -1  # "알 수 없음"을 특별한 값으로 처리
    }

    # ✅ 매핑 적용
    df["시술 당시 나이 숫자"] = df["시술 당시 나이"].map(age_mapping)

    # 배아 개수 대비 저장된 배아 수 비율 (배아 보존율)
    df["배아 보존율"] = df["저장된 배아 수"] / (df["총 생성 배아 수"] + 1)  # 0으로 나누는 것 방지
    df["이식 배아 비율"] = df["이식된 배아 수"] / (df["총 생성 배아 수"] + 1)
    df["배아 보존율 제곱"] =  df["배아 보존율"]* df["배아 보존율"]
    # ✅ 나이와 배아 수의 비율 변수 생성
    df["배아 수 대비 나이"] = df["시술 당시 나이 숫자"] / (df["이식된 배아 수"] + 1)

    # ✅ 추가 비율 Feature 생성
    df["배아 이식 경과일 대비 나이"] = df["배아 이식 경과일"] / (df["시술 당시 나이 숫자"] + 1)
    df["난자 활용 비율"] =df["혼합된 난자 수"] / (df["수집된 신선 난자 수"]+1)

    ivf_mapping = {'0회': 0, '1회': 1, '2회': 2, '3회': 3, '4회': 4, '5회': 5, '6회 이상': 6}

    # IVF 시술 횟수 컬럼을 매핑하여 정수형으로 변환
    df["IVF 시술 횟수"] = df["IVF 시술 횟수"].map(ivf_mapping)
    df["신선 난자 대비 IVF 시술 횟수 비율"] =df["IVF 시술 횟수"] / (df["수집된 신선 난자 수"]+1)
    df["난자당 평균 혼합 횟수"] =df["혼합된 난자 수"] / (df["IVF 시술 횟수"] + 1)
    df["1~2개 이식 여부"] = (df["이식된 배아 수"].between(1, 2)).astype(int)
    df["나이 26~36 여부"] = ((df["시술 당시 나이 숫자"] >= 26) & (df["시술 당시 나이 숫자"] <= 36)).astype(int)

    # 1️⃣ 이식된 배아 수 × 시술 당시 나이 숫자
    df["이식된 배아 수 × 시술 당시 나이"] = df["이식된 배아 수"] * df["시술 당시 나이 숫자"]
    # 2️⃣ 배아 이식 경과일 대비 나이 × 배아 수 대비 나이
    df["배아 이식 경과일 대비 나이 × 배아 수 대비 나이"] = df["배아 이식 경과일 대비 나이"] * df["배아 수 대비 나이"]
    # 3️⃣ 배아 수 대비 나이 / 총 생성 배아 수
    df["배아 수 대비 나이 / 총 생성 배아 수"] = df["배아 수 대비 나이"] / (df["총 생성 배아 수"] + 1)
    # 4️⃣ 이식된 배아 수 × 배아 이식 경과일 대비 나이
    df["이식된 배아 수 × 배아 이식 경과일 대비 나이"] = df["이식된 배아 수"] * df["배아 이식 경과일 대비 나이"]
    # 5️⃣ 시술 당시 나이 숫자 / 총 생성 배아 수
    df["시술 당시 나이 숫자 / 총 생성 배아 수"] = df["시술 당시 나이 숫자"] / (df["총 생성 배아 수"] + 1)
    
    # 새로운 파생 변수 생성
    df["시도_대비_이식_비율"] = (df["임신 시도 또는 마지막 임신 경과 연수"] / (df["배아 이식 경과일"] + 1))
    df["난자_활용도"] = (df["수집된 신선 난자 수"] / (df["총 생성 배아 수"] + 1))
    
    numeric_columns = [
        '임신 시도 또는 마지막 임신 경과 연수',
        "총 생성 배아 수",
        "미세주입된 난자 수",
        "미세주입에서 생성된 배아 수",
        "이식된 배아 수",
        "미세주입 배아 이식 수",
        "저장된 배아 수",
        "미세주입 후 저장된 배아 수",
        "해동된 배아 수",
        "해동 난자 수",
        "수집된 신선 난자 수",
        "저장된 신선 난자 수",
        "혼합된 난자 수",
        "파트너 정자와 혼합된 난자 수",
        "기증자 정자와 혼합된 난자 수",
        "난자 채취 경과일",
        "난자 해동 경과일",
        "난자 혼합 경과일",
        "배아 이식 경과일",
        "배아 해동 경과일"
        ]
    
    df[numeric_columns] = df[numeric_columns].fillna(0)

    # **PCA**로 차원 축소 후 군집화 수행 (군집 수는 3~6 사이로 실험)
    pca = PCA(n_components=7, random_state=42)
    X_pca = pca.fit_transform(df[numeric_columns])
    kmeans = KMeans(n_clusters=5, random_state=42)
    kmeans_clusters = kmeans.fit_predict(X_pca)
    
    df['cluster_group_1'] = kmeans_clusters
    
    pca = PCA(n_components=5, random_state=42)
    X_pca = pca.fit_transform(df[numeric_columns])
    kmeans = KMeans(n_clusters=2, random_state=42)
    kmeans_clusters = kmeans.fit_predict(X_pca)
    
    df['cluster_group_2'] = kmeans_clusters

    return df

# ✅ 데이터 로드
train = pd.read_csv("./data/train.csv")
test = pd.read_csv("./data/test.csv")

train = preprocess_data(train)
test = preprocess_data(test)

# LightGBM을 위한 범주형 변수 변환
train["시술 시기 코드"] = train["시술 시기 코드"].astype("category")
test["시술 시기 코드"] = test["시술 시기 코드"].astype("category")

# ✅ ID 제거
train = train.drop(columns=["ID"])
test_id = test["ID"]
test= test.drop(columns=["ID"])

hyperparameters = {
    # ✅ GPU 지원 모델 (속도 빠르고 성능 우수)
    "GBM": {},  # LightGBM (트리 부스팅, 속도 빠름)
    "XGB": {},  # XGBoost (트리 부스팅, 강력한 성능)
    "CAT": {},
    "NN_TORCH": {},
    "FASTAI": {},

    # ✅ CPU 지원 모델 (앙상블 다양성 확보)
   "RF": {},  # Random Forest (앙상블 성능 향상)
   "XT": {}   # Extra Trees (랜덤성이 강한 트리 모델)
}

hyperparameter_tune_kwargs = {
    'num_trials': 100,
    'searcher': 'bayes',  # 베이지안 최적화 방식
    'scheduler': 'local'
}
# ✅ 모델 저장 경로
save_path = "./model_save"

# 모델 학습
predictor = TabularPredictor(label="임신 성공 여부", problem_type="binary" ,eval_metric="roc_auc",path=save_path)
predictor.fit(train, presets="best_quality",
              time_limit=6000,
              hyperparameters=hyperparameters,
              hyperparameter_tune_kwargs=hyperparameter_tune_kwargs,  # ✅ 하이퍼파라미터 튜닝 추가
              num_bag_folds=10,
              auto_stack="True",
              dynamic_stacking=False,  # DyStack 비활성화
              refit_full=True,
              calibrate=True,  # ✅ 확률값 보정 활성화,
              num_stack_levels=2
              )
# Out:
# Fitted model: NeuralNetTorch_BAG_L3/faec2fd3 ...
# 	0.7398	 = Validation score   (roc_auc)
# 	257.35s	 = Training   runtime
# 	4.44s	 = Validation runtime
# Fitted model: NeuralNetTorch_BAG_L3/81457484 ...
# 	0.7352	 = Validation score   (roc_auc)
# 	259.28s	 = Training   runtime
# 	11.59s	 = Validation runtime
# Fitted model: NeuralNetTorch_BAG_L3/7fec8eff ...
# 	0.7364	 = Validation score   (roc_auc)
# 	264.39s	 = Training   runtime
# 	18.68s	 = Validation runtime
# Fitted model: NeuralNetTorch_BAG_L3/9588497f ...
# 	0.7397	 = Validation score   (roc_auc)
# 	254.58s	 = Training   runtime
# 	6.91s	 = Validation runtime
# Fitted model: NeuralNetTorch_BAG_L3/96c24cdc ...
# 	0.7392	 = Validation score   (roc_auc)
# 	53.75s	 = Training   runtime
# 	8.16s	 = Validation runtime
# Fitted model: NeuralNetTorch_BAG_L3/e78cf8e2 ...
# 	0.7379	 = Validation score   (roc_auc)
# 	48.36s	 = Training   runtime
# 	6.53s	 = Validation runtime
# Fitting model: WeightedEnsemble_L4 ... Training model for up to 360.00s of the 965.27s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1/T1': 0.208, 'ExtraTrees_BAG_L2': 0.167, 'NeuralNetFastAI_BAG_L1/e5e8c39a': 0.125, 'XGBoost_BAG_L1/T2': 0.125, 'NeuralNetTorch_BAG_L1/c9aa15a9': 0.083, 'LightGBM_BAG_L2/T13': 0.083, 'RandomForest_BAG_L2': 0.083, 'LightGBM_BAG_L2/T11': 0.042, 'LightGBM_BAG_L3/T14': 0.042, 'ExtraTrees_BAG_L3': 0.042}
# 	0.7413	 = Validation score   (roc_auc)
# 	56.17s	 = Training   runtime
# 	0.04s	 = Validation runtime
# AutoGluon training complete, total runtime = 5091.3s ... Best model: WeightedEnsemble_L4 | Estimated inference throughput: 61.5 rows/s (25636 batch size)
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T1_FULL ...
# 	2.16s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T2_FULL ...
# 	1.8s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T3_FULL ...
# 	2.07s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T4_FULL ...
# 	9.72s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T5_FULL ...
# 	1.42s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T6_FULL ...
# 	4.44s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T7_FULL ...
# 	1.54s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T8_FULL ...
# 	1.43s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T9_FULL ...
# 	8.26s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T10_FULL ...
# 	1.3s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T11_FULL ...
# 	4.95s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T12_FULL ...
# 	7.37s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T13_FULL ...
# 	6.39s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T14_FULL ...
# 	2.92s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T15_FULL ...
# 	8.27s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T16_FULL ...
# 	7.72s	 = Training   runtime
# Fitting model: RandomForest_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	9.74s	 = Training   runtime
# 	15.38s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L1/T1_FULL ...
# 	50.33s	 = Training   runtime
# Fitting model: ExtraTrees_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	8.47s	 = Training   runtime
# 	14.98s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/6e518f40_FULL ...
# 	Stopping at the best epoch learned earlier - 10.
# 	119.95s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/6fdb2c59_FULL ...
# 	Stopping at the best epoch learned earlier - 12.
# 	22.83s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/e5e8c39a_FULL ...
# 	Stopping at the best epoch learned earlier - 18.
# 	84.31s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/23ca15f2_FULL ...
# 	Stopping at the best epoch learned earlier - 2.
# 	111.94s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/1586b704_FULL ...
# 	Stopping at the best epoch learned earlier - 9.
# 	39.65s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/1d5e8d56_FULL ...
# 	Stopping at the best epoch learned earlier - 0.
# 	40.38s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/92c84848_FULL ...
# 	Stopping at the best epoch learned earlier - 6.
# 	24.86s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/a822a179_FULL ...
# 	Stopping at the best epoch learned earlier - 6.
# 	14.3s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/c3928ec7_FULL ...
# 	Stopping at the best epoch learned earlier - 0.
# 	12.77s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1/T1_FULL ...
# 	3.87s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1/T2_FULL ...
# 	3.79s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/c9aa15a9_FULL ...
# 	63.94s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/b0a50aa9_FULL ...
# 	21.11s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/fe2f6f64_FULL ...
# 	88.46s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/f6069f59_FULL ...
# 	55.01s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/d62dd1b4_FULL ...
# 	23.51s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/e62edf08_FULL ...
# 	23.87s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/467e28e7_FULL ...
# 	19.86s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/bcaae729_FULL ...
# 	9.02s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'CatBoost_BAG_L1/T1': 0.25, 'NeuralNetFastAI_BAG_L1/e5e8c39a': 0.167, 'XGBoost_BAG_L1/T2': 0.125, 'LightGBM_BAG_L1/T6': 0.083, 'NeuralNetFastAI_BAG_L1/6e518f40': 0.083, 'NeuralNetTorch_BAG_L1/c9aa15a9': 0.083, 'LightGBM_BAG_L1/T1': 0.042, 'LightGBM_BAG_L1/T5': 0.042, 'LightGBM_BAG_L1/T9': 0.042, 'RandomForest_BAG_L1': 0.042, 'NeuralNetTorch_BAG_L1/fe2f6f64': 0.042}
# 	36.14s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2/T1_FULL ...
# 	2.42s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2/T2_FULL ...
# 	2.27s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2/T3_FULL ...
# 	2.63s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2/T4_FULL ...
# 	14.26s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2/T5_FULL ...
# 	2.01s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2/T6_FULL ...
# 	5.59s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2/T7_FULL ...
# 	2.27s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2/T8_FULL ...
# 	2.03s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2/T9_FULL ...
# 	10.37s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2/T10_FULL ...
# 	1.83s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2/T11_FULL ...
# 	6.31s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2/T12_FULL ...
# 	9.15s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2/T13_FULL ...
# 	7.89s	 = Training   runtime
# Fitting model: RandomForest_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	25.66s	 = Training   runtime
# 	20.32s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L2/T1_FULL ...
# 	25.51s	 = Training   runtime
# Fitting model: ExtraTrees_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	10.03s	 = Training   runtime
# 	18.31s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/8ffa19b8_FULL ...
# 	Stopping at the best epoch learned earlier - 8.
# 	99.41s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/a4578aad_FULL ...
# 	Stopping at the best epoch learned earlier - 13.
# 	30.69s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/9b3229f6_FULL ...
# 	Stopping at the best epoch learned earlier - 4.
# 	15.75s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/b878415c_FULL ...
# 	Stopping at the best epoch learned earlier - 2.
# 	82.09s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/181ca752_FULL ...
# 	Stopping at the best epoch learned earlier - 3.
# 	80.13s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/1c23eb79_FULL ...
# 	Stopping at the best epoch learned earlier - 0.
# 	37.08s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/51d8cc10_FULL ...
# 	Stopping at the best epoch learned earlier - 7.
# 	18.06s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/99e0c252_FULL ...
# 	Stopping at the best epoch learned earlier - 0.
# 	22.17s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L2/T1_FULL ...
# 	5.13s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L2/T2_FULL ...
# 	5.0s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L2/T3_FULL ...
# 	6.85s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L2/2458f7a4_FULL ...
# 	25.05s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L2/8fee2b00_FULL ...
# 	58.84s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L2/6e430de8_FULL ...
# 	30.44s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L2/77882dfe_FULL ...
# 	32.7s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L2/aec7e567_FULL ...
# 	24.97s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L2/4455944c_FULL ...
# 	10.47s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L2/bfee4021_FULL ...
# 	10.25s	 = Training   runtime
# Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'ExtraTrees_BAG_L2': 0.182, 'CatBoost_BAG_L2/T1': 0.136, 'NeuralNetFastAI_BAG_L2/8ffa19b8': 0.136, 'LightGBM_BAG_L2/T7': 0.091, 'LightGBM_BAG_L2/T11': 0.091, 'RandomForest_BAG_L2': 0.091, 'LightGBM_BAG_L2/T4': 0.045, 'LightGBM_BAG_L2/T5': 0.045, 'LightGBM_BAG_L2/T13': 0.045, 'NeuralNetFastAI_BAG_L2/b878415c': 0.045, 'NeuralNetFastAI_BAG_L2/1c23eb79': 0.045, 'XGBoost_BAG_L2/T2': 0.045}
# 	34.24s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L3/T1_FULL ...
# 	2.37s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L3/T2_FULL ...
# 	2.42s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L3/T3_FULL ...
# 	2.53s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L3/T4_FULL ...
# 	12.53s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L3/T5_FULL ...
# 	1.98s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L3/T6_FULL ...
# 	5.95s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L3/T7_FULL ...
# 	2.26s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L3/T8_FULL ...
# 	2.01s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L3/T9_FULL ...
# 	9.65s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L3/T10_FULL ...
# 	1.79s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L3/T11_FULL ...
# 	6.43s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L3/T12_FULL ...
# 	9.71s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L3/T13_FULL ...
# 	6.94s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L3/T14_FULL ...
# 	3.06s	 = Training   runtime
# Fitting model: RandomForest_BAG_L3_FULL | Skipping fit via cloning parent ...
# 	26.15s	 = Training   runtime
# 	19.91s	 = Validation runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L3/T1_FULL ...
# 	18.8s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L3/T2_FULL ...
# 	3.85s	 = Training   runtime
# Fitting model: ExtraTrees_BAG_L3_FULL | Skipping fit via cloning parent ...
# 	9.76s	 = Training   runtime
# 	18.39s	 = Validation runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L3/955b3de7_FULL ...
# 	Stopping at the best epoch learned earlier - 8.
# 	100.64s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L3/37ea6121_FULL ...
# 	Stopping at the best epoch learned earlier - 0.
# 	42.53s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L3/180fadca_FULL ...
# 	Stopping at the best epoch learned earlier - 15.
# 	69.67s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L3/3834fc4c_FULL ...
# 	Stopping at the best epoch learned earlier - 6.
# 	72.07s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L3/3bc15686_FULL ...
# 	Stopping at the best epoch learned earlier - 2.
# 	17.34s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L3/60c09d7f_FULL ...
# 	Stopping at the best epoch learned earlier - 0.
# 	38.57s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L3/e19d2972_FULL ...
# 	Stopping at the best epoch learned earlier - 0.
# 	25.21s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L3/T1_FULL ...
# 	4.71s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L3/T2_FULL ...
# 	5.06s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L3/T3_FULL ...
# 	6.67s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L3/faec2fd3_FULL ...
# 	25.04s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L3/81457484_FULL ...
# 	39.74s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L3/7fec8eff_FULL ...
# 	43.68s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L3/9588497f_FULL ...
# 	83.87s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L3/96c24cdc_FULL ...
# 	15.01s	 = Training   runtime
# Fitting 1 L3 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L3/e78cf8e2_FULL ...
# 	10.58s	 = Training   runtime
# Fitting model: WeightedEnsemble_L4_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'CatBoost_BAG_L1/T1': 0.208, 'ExtraTrees_BAG_L2': 0.167, 'NeuralNetFastAI_BAG_L1/e5e8c39a': 0.125, 'XGBoost_BAG_L1/T2': 0.125, 'NeuralNetTorch_BAG_L1/c9aa15a9': 0.083, 'LightGBM_BAG_L2/T13': 0.083, 'RandomForest_BAG_L2': 0.083, 'LightGBM_BAG_L2/T11': 0.042, 'LightGBM_BAG_L3/T14': 0.042, 'ExtraTrees_BAG_L3': 0.042}
# 	56.17s	 = Training   runtime
# Refit complete, total runtime = 2350.24s ... Best model: "WeightedEnsemble_L4"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/home/najo/NAS/LGaimers6/Baseline/model_save")

# %%
# 예측
pred = predictor.predict_proba(test)  # ID 제거 후 예측
submission = pd.DataFrame({"ID": test_id, "probability": pred[1]})  # 1의 확률 사용

# 결과 병합 및 저장
submission.to_csv("Submission_PG.csv", index=False)

# 2️⃣ 가장 성능이 좋은 개별 모델 가져오기 (최신 AutoGluon 방식)
best_model = predictor.model_best

# 3️⃣ 보정 전 확률값 예측 (개별 모델 사용)
pred_uncalibrated = predictor.predict_proba(test, model=best_model)

# 4️⃣ 보정 전 결과 저장
submission_uncalibrated = pd.DataFrame({
    "ID": test_id,
    "probability": pred_uncalibrated[1]  # 1 클래스의 확률
})

# 5️⃣ CSV 파일로 저장
submission_uncalibrated.to_csv("improved_ansamble_autogluonV2.csv", index=False)

print("Submission file created: Submission_uncalibrate.csv")

# 리더보드 출력
predictor.leaderboard(silent=False)

# 1. Get the individual models and their weights from the ensemble
ensemble_model = predictor._trainer.load_model(best_model)

# 2. Access the model weights through the '_get_model_weights' method
model_weights = ensemble_model._get_model_weights() # Access the weights using the method

# 3. Print the model names and their corresponding weights
print("앙상블 모델 가중치:")
for model_name, weight in model_weights.items():
    print(f"  {model_name}: {weight}")

importance = predictor.feature_importance(train)
print(importance)

importance.head(40)

importance.tail(33)

# '특정 시술 유형' 별 '임신 성공 여부' 개수 확인
success_counts = train.groupby("총 생성 배아 수")["임신 성공 여부"].value_counts().unstack().fillna(0).astype(int)

# 결과 출력
print(success_counts)
# Out:
# These features in provided data are not utilized by the predictor and will be ignored: ['불임 원인 - 여성 요인', '난자 채취 경과일']
# Computing feature importance via permutation shuffling for 73 features using 5000 rows with 5 shuffle sets...
# Submission file created: Submission_uncalibrate.csv
#                                     model  score_val eval_metric  pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0                     WeightedEnsemble_L4   0.741325     roc_auc     495.739956  7109.872331                0.041535          56.171153            4       True        109
# 1                     WeightedEnsemble_L3   0.741132     roc_auc     357.514126  4702.242739                0.038728          34.242203            3       True         74
# 2                     WeightedEnsemble_L2   0.741012     roc_auc      57.334091  1617.968716                0.039353          36.138071            2       True         39
# 3                     LightGBM_BAG_L3/T14   0.740551     roc_auc     477.309170  7023.160859                1.030380          14.885583            3       True         88
# 4                      CatBoost_BAG_L3/T1   0.740540     roc_auc     476.825157  7156.272330                0.546367         147.997054            3       True         90
# 5         NeuralNetFastAI_BAG_L3/3834fc4c   0.740474     roc_auc     482.192199  7216.324297                5.913409         208.049022            3       True         96
# 6                      LightGBM_BAG_L2/T4   0.740462     roc_auc     253.887905  3457.200602                9.011507          80.858356            2       True         43
# 7                      CatBoost_BAG_L2/T1   0.740451     roc_auc     245.448985  3594.209337                0.572587         217.867090            2       True         54
# 8                     LightGBM_BAG_L2/T11   0.740446     roc_auc     247.980987  3411.626579                3.104590          35.284333            2       True         50
# 9                      CatBoost_BAG_L3/T2   0.740445     roc_auc     476.788803  7088.164608                0.510013          79.889332            3       True         91
# 10                     LightGBM_BAG_L2/T1   0.740377     roc_auc     245.690760  3387.821080                0.814363          11.478834            2       True         40
# 11                    LightGBM_BAG_L2/T13   0.740374     roc_auc     249.408216  3413.801241                4.531818          37.458995            2       True         52
# 12                      XGBoost_BAG_L2/T2   0.740356     roc_auc     248.598377  3484.799763                3.721980         108.457517            2       True         65
# 13                    LightGBM_BAG_L2/T12   0.740329     roc_auc     251.148217  3426.607014                6.271819          50.264768            2       True         51
# 14        NeuralNetFastAI_BAG_L2/9b3229f6   0.740329     roc_auc     248.287600  3442.464036                3.411203          66.121789            2       True         58
# 15                     LightGBM_BAG_L3/T1   0.740315     roc_auc     477.066468  7019.336140                0.787678          11.060865            3       True         75
# 16                     CatBoost_BAG_L1/T1   0.740224     roc_auc       0.547624   271.130403                0.547624         271.130403            1       True         18
# 17                      XGBoost_BAG_L2/T1   0.740195     roc_auc     248.376482  3447.515753                3.500084          71.173507            2       True         64
# 18        NeuralNetFastAI_BAG_L3/955b3de7   0.740181     roc_auc     483.343890  7271.928943                7.065100         263.653668            3       True         93
# 19                     LightGBM_BAG_L2/T9   0.740156     roc_auc     251.806739  3432.648289                6.930341          56.306043            2       True         48
# 20                     LightGBM_BAG_L2/T6   0.740153     roc_auc     247.089593  3405.402516                2.213195          29.060270            2       True         45
# 21                    LightGBM_BAG_L3/T11   0.740150     roc_auc     478.738581  7035.787115                2.459792          27.511840            3       True         85
# 22                     LightGBM_BAG_L3/T4   0.740149     roc_auc     484.218178  7061.391219                7.939388          53.115943            3       True         78
# 23                      XGBoost_BAG_L3/T2   0.740129     roc_auc     479.951987  7103.130547                3.673197          94.855272            3       True        101
# 24        NeuralNetFastAI_BAG_L2/8ffa19b8   0.740118     roc_auc     251.137241  3666.347033                6.260844         290.004787            2       True         56
# 25                    LightGBM_BAG_L3/T12   0.740104     roc_auc     481.926274  7050.719499                5.647484          42.444224            3       True         86
# 26                     LightGBM_BAG_L2/T3   0.740064     roc_auc     245.779158  3388.899502                0.902761          12.557256            2       True         42
# 27                      XGBoost_BAG_L3/T1   0.740048     roc_auc     479.852710  7074.820870                3.573920          66.545595            3       True        100
# 28                      XGBoost_BAG_L2/T3   0.740028     roc_auc     250.081935  3529.290897                5.205538         152.948651            2       True         66
# 29                     LightGBM_BAG_L2/T5   0.740008     roc_auc     245.491726  3385.351087                0.615328           9.008841            2       True         44
# 30        NeuralNetFastAI_BAG_L3/180fadca   0.739995     roc_auc     479.868078  7215.617906                3.589288         207.342631            3       True         95
# 31                    LightGBM_BAG_L3/T13   0.739982     roc_auc     479.823593  7042.044605                3.544804          33.769330            3       True         87
# 32                    LightGBM_BAG_L1/T15   0.739978     roc_auc      11.526919    47.339270               11.526919          47.339270            1       True         15
# 33                    LightGBM_BAG_L1/T14   0.739928     roc_auc       2.760631    18.076851                2.760631          18.076851            1       True         14
# 34                    LightGBM_BAG_L1/T12   0.739887     roc_auc       8.534101    33.078899                8.534101          33.078899            1       True         12
# 35                     LightGBM_BAG_L2/T8   0.739884     roc_auc     245.498298  3385.230852                0.621901           8.888606            2       True         47
# 36                     LightGBM_BAG_L1/T1   0.739871     roc_auc       1.212459     9.436981                1.212459           9.436981            1       True          1
# 37                    LightGBM_BAG_L1/T11   0.739840     roc_auc       4.370637    23.788301                4.370637          23.788301            1       True         11
# 38                    LightGBM_BAG_L1/T16   0.739821     roc_auc       8.940554    32.862108                8.940554          32.862108            1       True         16
# 39                     LightGBM_BAG_L3/T9   0.739819     roc_auc     482.173493  7053.954456                5.894703          45.679181            3       True         83
# 40                     LightGBM_BAG_L3/T3   0.739817     roc_auc     477.155076  7019.765872                0.876287          11.490596            3       True         77
# 41                     LightGBM_BAG_L3/T6   0.739804     roc_auc     478.233322  7032.936639                1.954533          24.661364            3       True         80
# 42                      XGBoost_BAG_L3/T3   0.739777     roc_auc     481.464224  7140.567753                5.185435         132.292477            3       True        102
# 43         NeuralNetTorch_BAG_L3/faec2fd3   0.739774     roc_auc     480.719841  7265.625281                4.441052         257.350006            3       True        103
# 44                     LightGBM_BAG_L1/T4   0.739774     roc_auc      11.304987    42.661699               11.304987          42.661699            1       True          4
# 45        NeuralNetFastAI_BAG_L3/3bc15686   0.739750     roc_auc     481.228167  7100.172372                4.949378          91.897097            3       True         97
# 46                      XGBoost_BAG_L1/T2   0.739746     roc_auc       3.660583   137.040675                3.660583         137.040675            1       True         30
# 47                    LightGBM_BAG_L1/T13   0.739744     roc_auc       6.769042    27.201768                6.769042          27.201768            1       True         13
# 48                     LightGBM_BAG_L1/T9   0.739724     roc_auc       8.782322    36.971992                8.782322          36.971992            1       True          9
# 49                     LightGBM_BAG_L3/T8   0.739720     roc_auc     476.984813  7016.969755                0.706023           8.694480            3       True         82
# 50         NeuralNetTorch_BAG_L3/9588497f   0.739677     roc_auc     483.192389  7262.851478                6.913599         254.576203            3       True        106
# 51                     LightGBM_BAG_L2/T2   0.739647     roc_auc     245.641042  3386.474592                0.764644          10.132346            2       True         41
# 52                     LightGBM_BAG_L1/T3   0.739635     roc_auc       1.199407     9.115729                1.199407           9.115729            1       True          3
# 53                     LightGBM_BAG_L1/T5   0.739623     roc_auc       0.720320     6.586354                0.720320           6.586354            1       True          5
# 54                     LightGBM_BAG_L3/T5   0.739608     roc_auc     476.901683  7017.008615                0.622893           8.733340            3       True         79
# 55                     LightGBM_BAG_L1/T6   0.739594     roc_auc       3.107229    18.329497                3.107229          18.329497            1       True          6
# 56                     LightGBM_BAG_L1/T8   0.739591     roc_auc       0.825610     6.318361                0.825610           6.318361            1       True          8
# 57         NeuralNetTorch_BAG_L2/77882dfe   0.739540     roc_auc     259.979699  3667.952222               15.103301         291.609976            2       True         70
# 58                     LightGBM_BAG_L2/T7   0.739498     roc_auc     245.582906  3388.152780                0.706509          11.810534            2       True         46
# 59                     LightGBM_BAG_L3/T2   0.739485     roc_auc     476.973803  7018.540577                0.695013          10.265302            3       True         76
# 60         NeuralNetTorch_BAG_L2/2458f7a4   0.739385     roc_auc     249.757025  3667.873351                4.880627         291.531105            2       True         67
# 61        NeuralNetFastAI_BAG_L2/51d8cc10   0.739372     roc_auc     247.182546  3438.865769                2.306148          62.523523            2       True         62
# 62        NeuralNetFastAI_BAG_L2/a4578aad   0.739363     roc_auc     248.282496  3594.937220                3.406099         218.594974            2       True         57
# 63                      XGBoost_BAG_L1/T1   0.739325     roc_auc       3.004471   103.176161                3.004471         103.176161            1       True         29
# 64                     LightGBM_BAG_L1/T7   0.739301     roc_auc       0.774097     6.507889                0.774097           6.507889            1       True          7
# 65         NeuralNetTorch_BAG_L3/96c24cdc   0.739233     roc_auc     484.443609  7062.028915                8.164819          53.753640            3       True        107
# 66                     LightGBM_BAG_L1/T2   0.739162     roc_auc       0.900882     7.309155                0.900882           7.309155            1       True          2
# 67        NeuralNetFastAI_BAG_L1/6fdb2c59   0.739100     roc_auc       2.270452    74.449077                2.270452          74.449077            1       True         21
# 68                     LightGBM_BAG_L3/T7   0.739043     roc_auc     476.902205  7017.607367                0.623415           9.332092            3       True         81
# 69                    LightGBM_BAG_L1/T10   0.739030     roc_auc       0.608065     5.449140                0.608065           5.449140            1       True         10
# 70         NeuralNetTorch_BAG_L2/6e430de8   0.738781     roc_auc     254.169904  3667.131374                9.293507         290.789128            2       True         69
# 71        NeuralNetFastAI_BAG_L1/e5e8c39a   0.738756     roc_auc       4.045347   268.092489                4.045347         268.092489            1       True         22
# 72        NeuralNetFastAI_BAG_L2/b878415c   0.738588     roc_auc     268.390551  3673.833925               23.514153         297.491678            2       True         59
# 73                      ExtraTrees_BAG_L2   0.738573     roc_auc     263.181872  3406.987218               18.305475          30.644972            2       True         55
# 74        NeuralNetFastAI_BAG_L3/60c09d7f   0.738561     roc_auc     505.503016  7086.831315               29.224227          78.556039            3       True         98
# 75                    LightGBM_BAG_L2/T10   0.738442     roc_auc     245.378114  3384.062450                0.501716           7.720204            2       True         49
# 76         NeuralNetTorch_BAG_L2/8fee2b00   0.738042     roc_auc     254.320787  3669.648335                9.444390         293.306089            2       True         68
# 77                    LightGBM_BAG_L3/T10   0.738014     roc_auc     476.855499  7016.008075                0.576709           7.732800            3       True         84
# 78         NeuralNetTorch_BAG_L3/e78cf8e2   0.737921     roc_auc     482.807695  7056.633032                6.528905          48.357757            3       True        108
# 79         NeuralNetTorch_BAG_L1/c9aa15a9   0.737822     roc_auc       3.526457   268.237734                3.526457         268.237734            1       True         31
# 80        NeuralNetFastAI_BAG_L1/6e518f40   0.737606     roc_auc       6.603852   271.963609                6.603852         271.963609            1       True         20
# 81        NeuralNetFastAI_BAG_L3/e19d2972   0.737604     roc_auc     491.856834  7068.417244               15.578045          60.141969            3       True         99
# 82                      ExtraTrees_BAG_L3   0.737540     roc_auc     494.668041  7038.815595               18.389251          30.540319            3       True         92
# 83        NeuralNetFastAI_BAG_L2/99e0c252   0.737300     roc_auc     255.702568  3424.601600               10.826171          48.259354            2       True         63
# 84        NeuralNetFastAI_BAG_L1/1586b704   0.737285     roc_auc       3.567175   115.166401                3.567175         115.166401            1       True         24
# 85        NeuralNetFastAI_BAG_L1/a822a179   0.737187     roc_auc       2.518116    50.563734                2.518116          50.563734            1       True         27
# 86         NeuralNetTorch_BAG_L1/fe2f6f64   0.737141     roc_auc       9.711981   266.386366                9.711981         266.386366            1       True         33
# 87         NeuralNetTorch_BAG_L2/aec7e567   0.736801     roc_auc     254.892934  3437.064950               10.016537          60.722704            2       True         71
# 88         NeuralNetTorch_BAG_L1/e62edf08   0.736434     roc_auc       4.028642    54.327068                4.028642          54.327068            1       True         36
# 89         NeuralNetTorch_BAG_L3/7fec8eff   0.736398     roc_auc     494.960064  7272.661813               18.681274         264.386537            3       True        105
# 90        NeuralNetFastAI_BAG_L2/181ca752   0.735908     roc_auc     256.869230  3610.677224               11.992832         234.334978            2       True         60
# 91         NeuralNetTorch_BAG_L1/f6069f59   0.735400     roc_auc      11.027075   264.640908               11.027075         264.640908            1       True         34
# 92         NeuralNetTorch_BAG_L3/81457484   0.735226     roc_auc     487.866334  7267.555309               11.587544         259.280034            3       True        104
# 93         NeuralNetTorch_BAG_L1/d62dd1b4   0.735081     roc_auc       5.590562    55.556475                5.590562          55.556475            1       True         35
# 94         NeuralNetTorch_BAG_L2/bfee4021   0.735074     roc_auc     251.084985  3414.911690                6.208588          38.569444            2       True         73
# 95                    RandomForest_BAG_L2   0.734772     roc_auc     265.199828  3424.640653               20.323431          48.298407            2       True         53
# 96        NeuralNetFastAI_BAG_L3/37ea6121   0.734677     roc_auc     500.477173  7267.848593               24.198383         259.573317            3       True         94
# 97        NeuralNetFastAI_BAG_L2/1c23eb79   0.734331     roc_auc     266.807176  3500.815026               21.930779         124.472780            2       True         61
# 98        NeuralNetFastAI_BAG_L1/23ca15f2   0.733687     roc_auc      29.885630   262.698024               29.885630         262.698024            1       True         23
# 99                    RandomForest_BAG_L3   0.733470     roc_auc     496.192929  7056.643913               19.914140          48.368637            3       True         89
# 100        NeuralNetTorch_BAG_L1/467e28e7   0.733414     roc_auc       4.681541    53.818441                4.681541          53.818441            1       True         37
# 101       NeuralNetFastAI_BAG_L1/92c84848   0.733125     roc_auc       2.991412    53.091759                2.991412          53.091759            1       True         26
# 102        NeuralNetTorch_BAG_L1/bcaae729   0.732274     roc_auc       6.043548    39.158736                6.043548          39.158736            1       True         38
# 103                     ExtraTrees_BAG_L1   0.731588     roc_auc      14.981487    26.016682               14.981487          26.016682            1       True         19
# 104       NeuralNetFastAI_BAG_L1/c3928ec7   0.728196     roc_auc       7.825632    48.988624                7.825632          48.988624            1       True         28
# 105                   RandomForest_BAG_L1   0.727686     roc_auc      15.376566    27.654546               15.376566          27.654546            1       True         17
# 106       NeuralNetFastAI_BAG_L1/1d5e8d56   0.727663     roc_auc      27.531108    90.844280               27.531108          90.844280            1       True         25
# 107        NeuralNetTorch_BAG_L1/b0a50aa9   0.725094     roc_auc       6.228532   267.890607                6.228532         267.890607            1       True         32
# 108        NeuralNetTorch_BAG_L2/4455944c   0.711099     roc_auc     249.565740  3417.443640                4.689342          41.101394            2       True         72
# 109                ExtraTrees_BAG_L1_FULL        NaN     roc_auc      14.981487     8.466424               14.981487           8.466424            1       True        128
# 110              RandomForest_BAG_L1_FULL        NaN     roc_auc      15.376566     9.741490               15.376566           9.741490            1       True        126
# 111                XGBoost_BAG_L3/T3_FULL        NaN     roc_auc            NaN  1647.812513                     NaN           6.666281            3       True        211
# 112                XGBoost_BAG_L3/T2_FULL        NaN     roc_auc            NaN  1646.210274                     NaN           5.064042            3       True        210
# 113                XGBoost_BAG_L3/T1_FULL        NaN     roc_auc            NaN  1645.861177                     NaN           4.714945            3       True        209
# 114                XGBoost_BAG_L2/T3_FULL        NaN     roc_auc            NaN   924.504156                     NaN           6.853893            2       True        175
# 115                XGBoost_BAG_L2/T2_FULL        NaN     roc_auc            NaN   922.650912                     NaN           5.000649            2       True        174
# 116                XGBoost_BAG_L2/T1_FULL        NaN     roc_auc            NaN   922.780952                     NaN           5.130689            2       True        173
# 117                XGBoost_BAG_L1/T2_FULL        NaN     roc_auc            NaN     3.787931                     NaN           3.787931            1       True        139
# 118                XGBoost_BAG_L1/T1_FULL        NaN     roc_auc            NaN     3.868954                     NaN           3.868954            1       True        138
# 119              WeightedEnsemble_L4_FULL        NaN     roc_auc            NaN  1710.143557                     NaN          56.171153            4       True        218
# 120              WeightedEnsemble_L3_FULL        NaN     roc_auc            NaN  1269.399964                     NaN          34.242203            3       True        183
# 121              WeightedEnsemble_L2_FULL        NaN     roc_auc            NaN   472.937407                     NaN          36.138071            2       True        148
# 122              RandomForest_BAG_L3_FULL        NaN     roc_auc            NaN  1667.291269               19.914140          26.145037            3       True        198
# 123              RandomForest_BAG_L2_FULL        NaN     roc_auc            NaN   943.311734               20.323431          25.661471            2       True        162
# 124   NeuralNetTorch_BAG_L3/faec2fd3_FULL        NaN     roc_auc            NaN  1666.182220                     NaN          25.035988            3       True        212
# 125   NeuralNetTorch_BAG_L3/e78cf8e2_FULL        NaN     roc_auc            NaN  1651.730537                     NaN          10.584306            3       True        217
# 126   NeuralNetTorch_BAG_L3/96c24cdc_FULL        NaN     roc_auc            NaN  1656.158569                     NaN          15.012337            3       True        216
# 127   NeuralNetTorch_BAG_L3/9588497f_FULL        NaN     roc_auc            NaN  1725.015601                     NaN          83.869369            3       True        215
# 128   NeuralNetTorch_BAG_L3/81457484_FULL        NaN     roc_auc            NaN  1680.888545                     NaN          39.742313            3       True        213
# 129   NeuralNetTorch_BAG_L3/7fec8eff_FULL        NaN     roc_auc            NaN  1684.821371                     NaN          43.675139            3       True        214
# 130   NeuralNetTorch_BAG_L2/bfee4021_FULL        NaN     roc_auc            NaN   927.901359                     NaN          10.251096            2       True        182
# 131   NeuralNetTorch_BAG_L2/aec7e567_FULL        NaN     roc_auc            NaN   942.621508                     NaN          24.971245            2       True        180
# 132   NeuralNetTorch_BAG_L2/8fee2b00_FULL        NaN     roc_auc            NaN   976.486468                     NaN          58.836205            2       True        177
# 133   NeuralNetTorch_BAG_L2/77882dfe_FULL        NaN     roc_auc            NaN   950.346879                     NaN          32.696616            2       True        179
# 134   NeuralNetTorch_BAG_L2/6e430de8_FULL        NaN     roc_auc            NaN   948.093138                     NaN          30.442874            2       True        178
# 135   NeuralNetTorch_BAG_L2/4455944c_FULL        NaN     roc_auc            NaN   928.124243                     NaN          10.473980            2       True        181
# 136   NeuralNetTorch_BAG_L2/2458f7a4_FULL        NaN     roc_auc            NaN   942.696909                     NaN          25.046646            2       True        176
# 137   NeuralNetTorch_BAG_L1/fe2f6f64_FULL        NaN     roc_auc            NaN    88.463682                     NaN          88.463682            1       True        142
# 138   NeuralNetTorch_BAG_L1/f6069f59_FULL        NaN     roc_auc            NaN    55.007603                     NaN          55.007603            1       True        143
# 139   NeuralNetTorch_BAG_L1/e62edf08_FULL        NaN     roc_auc            NaN    23.874607                     NaN          23.874607            1       True        145
# 140   NeuralNetTorch_BAG_L1/d62dd1b4_FULL        NaN     roc_auc            NaN    23.512638                     NaN          23.512638            1       True        144
# 141   NeuralNetTorch_BAG_L1/c9aa15a9_FULL        NaN     roc_auc            NaN    63.944294                     NaN          63.944294            1       True        140
# 142   NeuralNetTorch_BAG_L1/bcaae729_FULL        NaN     roc_auc            NaN     9.016782                     NaN           9.016782            1       True        147
# 143   NeuralNetTorch_BAG_L1/b0a50aa9_FULL        NaN     roc_auc            NaN    21.112726                     NaN          21.112726            1       True        141
# 144   NeuralNetTorch_BAG_L1/467e28e7_FULL        NaN     roc_auc            NaN    19.863523                     NaN          19.863523            1       True        146
# 145  NeuralNetFastAI_BAG_L3/e19d2972_FULL        NaN     roc_auc            NaN  1666.359597                     NaN          25.213365            3       True        208
# 146  NeuralNetFastAI_BAG_L3/955b3de7_FULL        NaN     roc_auc            NaN  1741.789804                     NaN         100.643572            3       True        202
# 147  NeuralNetFastAI_BAG_L3/60c09d7f_FULL        NaN     roc_auc            NaN  1679.713118                     NaN          38.566886            3       True        207
# 148  NeuralNetFastAI_BAG_L3/3bc15686_FULL        NaN     roc_auc            NaN  1658.490455                     NaN          17.344223            3       True        206
# 149  NeuralNetFastAI_BAG_L3/3834fc4c_FULL        NaN     roc_auc            NaN  1713.215161                     NaN          72.068929            3       True        205
# 150  NeuralNetFastAI_BAG_L3/37ea6121_FULL        NaN     roc_auc            NaN  1683.675853                     NaN          42.529621            3       True        203
# 151  NeuralNetFastAI_BAG_L3/180fadca_FULL        NaN     roc_auc            NaN  1710.816895                     NaN          69.670663            3       True        204
# 152  NeuralNetFastAI_BAG_L2/b878415c_FULL        NaN     roc_auc            NaN   999.735970                     NaN          82.085707            2       True        168
# 153  NeuralNetFastAI_BAG_L2/a4578aad_FULL        NaN     roc_auc            NaN   948.341333                     NaN          30.691070            2       True        166
# 154  NeuralNetFastAI_BAG_L2/9b3229f6_FULL        NaN     roc_auc            NaN   933.405197                     NaN          15.754934            2       True        167
# 155  NeuralNetFastAI_BAG_L2/99e0c252_FULL        NaN     roc_auc            NaN   939.822709                     NaN          22.172446            2       True        172
# 156  NeuralNetFastAI_BAG_L2/8ffa19b8_FULL        NaN     roc_auc            NaN  1017.055462                     NaN          99.405199            2       True        165
# 157  NeuralNetFastAI_BAG_L2/51d8cc10_FULL        NaN     roc_auc            NaN   935.712687                     NaN          18.062424            2       True        171
# 158  NeuralNetFastAI_BAG_L2/1c23eb79_FULL        NaN     roc_auc            NaN   954.733341                     NaN          37.083078            2       True        170
# 159  NeuralNetFastAI_BAG_L2/181ca752_FULL        NaN     roc_auc            NaN   997.784832                     NaN          80.134569            2       True        169
# 160  NeuralNetFastAI_BAG_L1/e5e8c39a_FULL        NaN     roc_auc            NaN    84.313080                     NaN          84.313080            1       True        131
# 161  NeuralNetFastAI_BAG_L1/c3928ec7_FULL        NaN     roc_auc            NaN    12.768354                     NaN          12.768354            1       True        137
# 162  NeuralNetFastAI_BAG_L1/a822a179_FULL        NaN     roc_auc            NaN    14.296540                     NaN          14.296540            1       True        136
# 163  NeuralNetFastAI_BAG_L1/92c84848_FULL        NaN     roc_auc            NaN    24.858888                     NaN          24.858888            1       True        135
# 164  NeuralNetFastAI_BAG_L1/6fdb2c59_FULL        NaN     roc_auc            NaN    22.830495                     NaN          22.830495            1       True        130
# 165  NeuralNetFastAI_BAG_L1/6e518f40_FULL        NaN     roc_auc            NaN   119.952618                     NaN         119.952618            1       True        129
# 166  NeuralNetFastAI_BAG_L1/23ca15f2_FULL        NaN     roc_auc            NaN   111.937857                     NaN         111.937857            1       True        132
# 167  NeuralNetFastAI_BAG_L1/1d5e8d56_FULL        NaN     roc_auc            NaN    40.380589                     NaN          40.380589            1       True        134
# 168  NeuralNetFastAI_BAG_L1/1586b704_FULL        NaN     roc_auc            NaN    39.645634                     NaN          39.645634            1       True        133
# 169               LightGBM_BAG_L3/T9_FULL        NaN     roc_auc            NaN  1650.797564                     NaN           9.651332            3       True        192
# 170               LightGBM_BAG_L3/T8_FULL        NaN     roc_auc            NaN  1643.156136                     NaN           2.009904            3       True        191
# 171               LightGBM_BAG_L3/T7_FULL        NaN     roc_auc            NaN  1643.402066                     NaN           2.255834            3       True        190
# 172               LightGBM_BAG_L3/T6_FULL        NaN     roc_auc            NaN  1647.093273                     NaN           5.947041            3       True        189
# 173               LightGBM_BAG_L3/T5_FULL        NaN     roc_auc            NaN  1643.127794                     NaN           1.981562            3       True        188
# 174               LightGBM_BAG_L3/T4_FULL        NaN     roc_auc            NaN  1653.672729                     NaN          12.526497            3       True        187
# 175               LightGBM_BAG_L3/T3_FULL        NaN     roc_auc            NaN  1643.677524                     NaN           2.531292            3       True        186
# 176               LightGBM_BAG_L3/T2_FULL        NaN     roc_auc            NaN  1643.562861                     NaN           2.416629            3       True        185
# 177               LightGBM_BAG_L3/T1_FULL        NaN     roc_auc            NaN  1643.518991                     NaN           2.372759            3       True        184
# 178              LightGBM_BAG_L3/T14_FULL        NaN     roc_auc            NaN  1644.211225                     NaN           3.064993            3       True        197
# 179              LightGBM_BAG_L3/T13_FULL        NaN     roc_auc            NaN  1648.085193                     NaN           6.938962            3       True        196
# 180              LightGBM_BAG_L3/T12_FULL        NaN     roc_auc            NaN  1650.857599                     NaN           9.711367            3       True        195
# 181              LightGBM_BAG_L3/T11_FULL        NaN     roc_auc            NaN  1647.572126                     NaN           6.425894            3       True        194
# 182              LightGBM_BAG_L3/T10_FULL        NaN     roc_auc            NaN  1642.939652                     NaN           1.793421            3       True        193
# 183               LightGBM_BAG_L2/T9_FULL        NaN     roc_auc            NaN   928.019268                     NaN          10.369005            2       True        157
# 184               LightGBM_BAG_L2/T8_FULL        NaN     roc_auc            NaN   919.681748                     NaN           2.031485            2       True        156
# 185               LightGBM_BAG_L2/T7_FULL        NaN     roc_auc            NaN   919.919622                     NaN           2.269359            2       True        155
# 186               LightGBM_BAG_L2/T6_FULL        NaN     roc_auc            NaN   923.243898                     NaN           5.593635            2       True        154
# 187               LightGBM_BAG_L2/T5_FULL        NaN     roc_auc            NaN   919.658615                     NaN           2.008352            2       True        153
# 188               LightGBM_BAG_L2/T4_FULL        NaN     roc_auc            NaN   931.913171                     NaN          14.262908            2       True        152
# 189               LightGBM_BAG_L2/T3_FULL        NaN     roc_auc            NaN   920.282548                     NaN           2.632285            2       True        151
# 190               LightGBM_BAG_L2/T2_FULL        NaN     roc_auc            NaN   919.922502                     NaN           2.272239            2       True        150
# 191               LightGBM_BAG_L2/T1_FULL        NaN     roc_auc            NaN   920.074819                     NaN           2.424556            2       True        149
# 192              LightGBM_BAG_L2/T13_FULL        NaN     roc_auc            NaN   925.535869                     NaN           7.885606            2       True        161
# 193              LightGBM_BAG_L2/T12_FULL        NaN     roc_auc            NaN   926.796843                     NaN           9.146580            2       True        160
# 194              LightGBM_BAG_L2/T11_FULL        NaN     roc_auc            NaN   923.957767                     NaN           6.307504            2       True        159
# 195              LightGBM_BAG_L2/T10_FULL        NaN     roc_auc            NaN   919.476716                     NaN           1.826452            2       True        158
# 196               LightGBM_BAG_L1/T9_FULL        NaN     roc_auc            NaN     8.256533                     NaN           8.256533            1       True        118
# 197               LightGBM_BAG_L1/T8_FULL        NaN     roc_auc            NaN     1.425771                     NaN           1.425771            1       True        117
# 198               LightGBM_BAG_L1/T7_FULL        NaN     roc_auc            NaN     1.540830                     NaN           1.540830            1       True        116
# 199               LightGBM_BAG_L1/T6_FULL        NaN     roc_auc            NaN     4.436874                     NaN           4.436874            1       True        115
# 200               LightGBM_BAG_L1/T5_FULL        NaN     roc_auc            NaN     1.416406                     NaN           1.416406            1       True        114
# 201               LightGBM_BAG_L1/T4_FULL        NaN     roc_auc            NaN     9.723389                     NaN           9.723389            1       True        113
# 202               LightGBM_BAG_L1/T3_FULL        NaN     roc_auc            NaN     2.068282                     NaN           2.068282            1       True        112
# 203               LightGBM_BAG_L1/T2_FULL        NaN     roc_auc            NaN     1.796761                     NaN           1.796761            1       True        111
# 204               LightGBM_BAG_L1/T1_FULL        NaN     roc_auc            NaN     2.159613                     NaN           2.159613            1       True        110
# 205              LightGBM_BAG_L1/T16_FULL        NaN     roc_auc            NaN     7.720788                     NaN           7.720788            1       True        125
# 206              LightGBM_BAG_L1/T15_FULL        NaN     roc_auc            NaN     8.271072                     NaN           8.271072            1       True        124
# 207              LightGBM_BAG_L1/T14_FULL        NaN     roc_auc            NaN     2.917567                     NaN           2.917567            1       True        123
# 208              LightGBM_BAG_L1/T13_FULL        NaN     roc_auc            NaN     6.391084                     NaN           6.391084            1       True        122
# 209              LightGBM_BAG_L1/T12_FULL        NaN     roc_auc            NaN     7.365656                     NaN           7.365656            1       True        121
# 210              LightGBM_BAG_L1/T11_FULL        NaN     roc_auc            NaN     4.951475                     NaN           4.951475            1       True        120
# 211              LightGBM_BAG_L1/T10_FULL        NaN     roc_auc            NaN     1.301580                     NaN           1.301580            1       True        119
# 212                ExtraTrees_BAG_L3_FULL        NaN     roc_auc            NaN  1650.907410               18.389251           9.761178            3       True        201
# 213                ExtraTrees_BAG_L2_FULL        NaN     roc_auc            NaN   927.678207               18.305475          10.027944            2       True        164
# 214               CatBoost_BAG_L3/T2_FULL        NaN     roc_auc            NaN  1644.996582                     NaN           3.850350            3       True        200
# 215               CatBoost_BAG_L3/T1_FULL        NaN     roc_auc            NaN  1659.942368                     NaN          18.796136            3       True        199
# 216               CatBoost_BAG_L2/T1_FULL        NaN     roc_auc            NaN   943.159984                     NaN          25.509721            2       True        163
# 217               CatBoost_BAG_L1/T1_FULL        NaN     roc_auc            NaN    50.326817                     NaN          50.326817            1       True        127
# 앙상블 모델 가중치:
#   CatBoost_BAG_L1/T1: 0.20833333333333334
#   NeuralNetFastAI_BAG_L1/e5e8c39a: 0.125
#   XGBoost_BAG_L1/T2: 0.125
#   NeuralNetTorch_BAG_L1/c9aa15a9: 0.08333333333333333
#   LightGBM_BAG_L2/T11: 0.041666666666666664
#   LightGBM_BAG_L2/T13: 0.08333333333333333
#   RandomForest_BAG_L2: 0.08333333333333333
#   ExtraTrees_BAG_L2: 0.16666666666666666
#   LightGBM_BAG_L3/T14: 0.041666666666666664
#   ExtraTrees_BAG_L3: 0.041666666666666664
# 	19617.16s	= Expected runtime (3923.43s per shuffle set)
# 	13200.93s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                  importance    stddev   p_value  n  p99_high   p99_low
# 시술 당시 나이 숫자        0.011616  0.003067  0.000533  5  0.017931  0.005301
# 배아 수 대비 나이         0.011504  0.002700  0.000339  5  0.017064  0.005945
# 배아 이식 경과일 대비 나이    0.010040  0.002282  0.000299  5  0.014740  0.005341
# 난자_활용도             0.007061  0.001125  0.000075  5  0.009377  0.004745
# 시술 시기 코드           0.006759  0.000939  0.000044  5  0.008692  0.004825
# ...                     ...       ...       ... ..       ...       ...
# DI 임신 횟수           0.000152  0.000100  0.013575  5  0.000357 -0.000053
# 저장된 신선 난자 수        0.000134  0.000149  0.057462  5  0.000441 -0.000173
# 난자 혼합 경과일          0.000121  0.000180  0.103368  5  0.000491 -0.000249
# 배아 해동 경과일          0.000088  0.000088  0.044759  5  0.000270 -0.000094
# 난자 해동 경과일          0.000000  0.000000  0.500000  5  0.000000  0.000000
#
# [73 rows x 6 columns]
# 임신 성공 여부       0     1
# 총 생성 배아 수
# 0.0        49660  9980
# 1.0        13779  1444
# 2.0        15734  3456
# 3.0        15884  5068
# 4.0        15619  5993
# 5.0        14176  6234
# 6.0        12608  6015
# 7.0        10606  5423
# 8.0         8853  4767
# 9.0         7187  3944
# 10.0        5798  3267
# 11.0        4489  2601
# 12.0        3704  2016
# 13.0        2739  1582
# 14.0        2164  1196
# 15.0        1616   900
# 16.0        1251   665
# 17.0        1019   485
# 18.0         778   339
# 19.0         553   246
# 20.0         457   183
# 21.0         339   122
# 22.0         265    89
# 23.0         210    56
# 24.0         156    39
# 25.0         130    33
# 26.0          83    22
# 27.0          64    20
# 28.0          43     8
# 29.0          36    10
# 30.0          33     7
# 31.0          22     3
# 32.0          17     6
# 33.0          10     2
# 34.0          10     5
# 35.0           4     0
# 36.0           6     1
# 37.0           6     1
# 38.0           3     0
# 40.0           1     0
# 41.0           2     0
# 42.0           3     0
# 43.0           1     0
# 44.0           3     0
# 51.0           2     0
