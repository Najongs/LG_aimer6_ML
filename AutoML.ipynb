# %%
from autogluon.tabular import TabularDataset, TabularPredictor
from sklearn.preprocessing import  OrdinalEncoder, StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from imblearn.over_sampling import ADASYN
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor

numeric_columns = [
    "임신 시도 또는 마지막 임신 경과 연수",
    "총 생성 배아 수",
    "미세주입된 난자 수",
    "미세주입에서 생성된 배아 수",
    "이식된 배아 수",
    "미세주입 배아 이식 수",
    "저장된 배아 수",
    "미세주입 후 저장된 배아 수",
    "해동된 배아 수",
    "해동 난자 수",
    "수집된 신선 난자 수",
    "저장된 신선 난자 수",
    "혼합된 난자 수",
    "파트너 정자와 혼합된 난자 수",
    "기증자 정자와 혼합된 난자 수",
    "난자 채취 경과일",
    "난자 해동 경과일",
    "난자 혼합 경과일",
    "배아 이식 경과일",
    "배아 해동 경과일"
]

categorical_columns = [
    "시술 시기 코드",
    "시술 당시 나이",
    "시술 유형",
    "특정 시술 유형",
    "배란 자극 여부",
    "배란 유도 유형",
    "단일 배아 이식 여부",
    "착상 전 유전 검사 사용 여부",
    "착상 전 유전 진단 사용 여부",
    "남성 주 불임 원인",
    "남성 부 불임 원인",
    "여성 주 불임 원인",
    "여성 부 불임 원인",
    "부부 주 불임 원인",
    "부부 부 불임 원인",
    "불명확 불임 원인",
    "불임 원인 - 난관 질환",
    "불임 원인 - 남성 요인",
    "불임 원인 - 배란 장애",
    "불임 원인 - 여성 요인",
    "불임 원인 - 자궁경부 문제",
    "불임 원인 - 자궁내막증",
    "불임 원인 - 정자 농도",
    "불임 원인 - 정자 면역학적 요인",
    "불임 원인 - 정자 운동성",
    "불임 원인 - 정자 형태",
    "배아 생성 주요 이유",
    "총 시술 횟수",
    "클리닉 내 총 시술 횟수",
    "IVF 시술 횟수",
    "DI 시술 횟수",
    "총 임신 횟수",
    "IVF 임신 횟수",
    "DI 임신 횟수",
    "총 출산 횟수",
    "IVF 출산 횟수",
    "DI 출산 횟수",
    "난자 출처",
    "정자 출처",
    "난자 기증자 나이",
    "정자 기증자 나이",
    "동결 배아 사용 여부",
    "신선 배아 사용 여부",
    "기증 배아 사용 여부",
    "대리모 여부",
    "PGD 시술 여부",
    "PGS 시술 여부"
]

train = pd.read_csv('./data/train.csv').drop(columns=['ID'])
test = pd.read_csv('./data/test.csv').drop(columns=['ID'])

# 카테고리형 컬럼들을 문자열로 변환
for col in categorical_columns:
    train[col] = train[col].astype(str)
    test[col] = test[col].astype(str)

ordinal_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

X_train_encoded = train.copy()
X_train_encoded[categorical_columns] = ordinal_encoder.fit_transform(train[categorical_columns])
X_test_encoded = test.copy()
X_test_encoded[categorical_columns] = ordinal_encoder.transform(test[categorical_columns])

X_train_encoded[numeric_columns] = X_train_encoded[numeric_columns].fillna(0)
X_test_encoded[numeric_columns] = X_test_encoded[numeric_columns].fillna(0)

# **PCA**로 차원 축소 후 군집화 수행 (군집 수는 3~6 사이로 실험)
pca = PCA(n_components=7, random_state=42)
X_pca = pca.fit_transform(X_train_encoded[numeric_columns])

kmeans = KMeans(n_clusters=5, random_state=42)
kmeans_clusters = kmeans.fit_predict(X_pca)

# 새로운 군집 피처 추가
X_train_encoded['cluster_group'] = kmeans_clusters
X_test_encoded['cluster_group'] = kmeans.predict(pca.transform(X_test_encoded[numeric_columns]))

# 새로운 파생 변수 생성
X_train_encoded["시도_대비_이식_비율"] = (X_train_encoded["임신 시도 또는 마지막 임신 경과 연수"] / (X_train_encoded["배아 이식 경과일"] + 1))
X_train_encoded["난자_활용도"] = (X_train_encoded
                             ["수집된 신선 난자 수"] / (X_train_encoded["총 생성 배아 수"] + 1))
X_test_encoded["시도_대비_이식_비율"] = (X_test_encoded["임신 시도 또는 마지막 임신 경과 연수"] / (X_test_encoded["배아 이식 경과일"] + 1))
X_test_encoded["난자_활용도"] = (X_test_encoded["수집된 신선 난자 수"] / (X_test_encoded["총 생성 배아 수"] + 1))

X_train = X_train_encoded.drop('임신 성공 여부', axis=1)
y_train = X_train_encoded['임신 성공 여부']

# Function to calculate VIF for each feature
def calculate_vif(df):
    vif_data = pd.DataFrame()
    vif_data["Feature"] = df.columns
    vif_data["VIF"] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
    return vif_data

# Calculate VIF for the selected features in X
vif_df = calculate_vif(X_train)

# Remove features with VIF >= 10
high_vif_features = vif_df[vif_df["VIF"] >= 23]["Feature"].tolist()
X_reduced = X_train.drop(columns=high_vif_features)

# Recalculate VIF for the reduced feature set
reduced_vif_df = calculate_vif(X_reduced)

X_train_encoded = X_train_encoded[reduced_vif_df['Feature']]
X_test_encoded = X_test_encoded[reduced_vif_df['Feature']]

X_train_encoded['임신 성공 여부'] = train['임신 성공 여부']
# Out:
# /home/najo/.conda/envs/dip/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1784: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.uncentered_tss
# /home/najo/.conda/envs/dip/lib/python3.10/site-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /home/najo/.conda/envs/dip/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1784: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.uncentered_tss

# %%
train = TabularDataset(X_train_encoded)
test = TabularDataset(X_test_encoded)
predictor = TabularPredictor(label='임신 성공 여부', eval_metric='roc_auc',).fit(train, time_limit=3600,  num_cpus=8, num_gpus =3, presets='best_quality')

ld_board = predictor.leaderboard(train, silent=True)
ld_board
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20250220_060351"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.10.15
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #136~20.04.1-Ubuntu SMP Thu Nov 14 16:38:05 UTC 2024
# CPU Count:          48
# Memory Avail:       231.06 GB / 251.54 GB (91.9%)
# Disk Space Avail:   1358.99 GB / 1875.30 GB (72.5%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-02-20 15:03:53,901	INFO worker.py:1810 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 		Context path: "/home/najo/NAS/LGaimers6/Baseline/AutogluonModels/ag-20250220_060351/ds_sub_fit/sub_fit_ho"
# (_dystack pid=258813) Running DyStack sub-fit ...
# (_dystack pid=258813) Beginning AutoGluon training ... Time limit = 896s
# (_dystack pid=258813) AutoGluon will save models to "/home/najo/NAS/LGaimers6/Baseline/AutogluonModels/ag-20250220_060351/ds_sub_fit/sub_fit_ho"
# (_dystack pid=258813) Train Data Rows:    227867
# (_dystack pid=258813) Train Data Columns: 39
# (_dystack pid=258813) Label Column:       임신 성공 여부
# (_dystack pid=258813) Problem Type:       binary
# (_dystack pid=258813) Preprocessing data ...
# (_dystack pid=258813) Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# (_dystack pid=258813) Using Feature Generators to preprocess the data ...
# (_dystack pid=258813) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=258813) 	Available Memory:                    234124.71 MB
# (_dystack pid=258813) 	Train Data (Original)  Memory Usage: 66.93 MB (0.0% of available memory)
# (_dystack pid=258813) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=258813) 	Stage 1 Generators:
# (_dystack pid=258813) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=258813) 			Note: Converting 15 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=258813) 	Stage 2 Generators:
# (_dystack pid=258813) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=258813) 	Stage 3 Generators:
# (_dystack pid=258813) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=258813) 	Stage 4 Generators:
# (_dystack pid=258813) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=258813) 	Stage 5 Generators:
# (_dystack pid=258813) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=258813) 	Useless Original Features (Count: 2): ['불임 원인 - 여성 요인', '난자 채취 경과일']
# (_dystack pid=258813) 		These features carry no predictive signal and should be manually investigated.
# (_dystack pid=258813) 		This is typically a feature which has the same value for all rows.
# (_dystack pid=258813) 		These features do not need to be present at inference time.
# (_dystack pid=258813) 	Unused Original Features (Count: 3): ['불임 원인 - 정자 면역학적 요인', '불임 원인 - 정자 운동성', '난자 해동 경과일']
# (_dystack pid=258813) 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# (_dystack pid=258813) 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# (_dystack pid=258813) 		These features do not need to be present at inference time.
# (_dystack pid=258813) 		('float', []) : 3 | ['불임 원인 - 정자 면역학적 요인', '불임 원인 - 정자 운동성', '난자 해동 경과일']
# (_dystack pid=258813) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=258813) 		('float', []) : 33 | ['시술 시기 코드', '시술 당시 나이', '임신 시도 또는 마지막 임신 경과 연수', '특정 시술 유형', '단일 배아 이식 여부', ...]
# (_dystack pid=258813) 		('int', [])   :  1 | ['cluster_group']
# (_dystack pid=258813) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=258813) 		('float', [])     : 21 | ['시술 시기 코드', '시술 당시 나이', '임신 시도 또는 마지막 임신 경과 연수', '특정 시술 유형', '단일 배아 이식 여부', ...]
# (_dystack pid=258813) 		('int', [])       :  1 | ['cluster_group']
# (_dystack pid=258813) 		('int', ['bool']) : 12 | ['남성 부 불임 원인', '여성 주 불임 원인', '여성 부 불임 원인', '부부 부 불임 원인', '불명확 불임 원인', ...]
# (_dystack pid=258813) 	1.1s = Fit runtime
# (_dystack pid=258813) 	34 features in original data used to generate 34 features in processed data.
# (_dystack pid=258813) 	Train Data (Processed) Memory Usage: 39.99 MB (0.0% of available memory)
# (_dystack pid=258813) Data preprocessing and feature engineering runtime = 1.23s ...
# (_dystack pid=258813) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=258813) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=258813) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=258813) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=258813) User-specified model hyperparameters to be fit:
# (_dystack pid=258813) {
# (_dystack pid=258813) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=258813) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=258813) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=258813) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=258813) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=258813) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=258813) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=258813) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=258813) }
# (_dystack pid=258813) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=258813) Fitting 110 L1 models, fit_strategy="sequential" ...
# (_dystack pid=258813) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 596.55s of the 895.04s of remaining time.
# (_dystack pid=258813) 	0.6535	 = Validation score   (roc_auc)
# (_dystack pid=258813) 	0.22s	 = Training   runtime
# (_dystack pid=258813) 	41.24s	 = Validation runtime
# (_dystack pid=258813) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 554.75s of the 853.24s of remaining time.
# (_dystack pid=258813) 	0.6296	 = Validation score   (roc_auc)
# (_dystack pid=258813) 	0.22s	 = Training   runtime
# (_dystack pid=258813) 	41.14s	 = Validation runtime
# (_dystack pid=258813) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 513.10s of the 811.59s of remaining time.
# (_dystack pid=258813) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.12%)
# (_dystack pid=258813) 	0.7335	 = Validation score   (roc_auc)
# (_dystack pid=258813) 	23.04s	 = Training   runtime
# (_dystack pid=258813) 	4.75s	 = Validation runtime
# (_dystack pid=258813) Fitting model: LightGBM_BAG_L1 ... Training model for up to 487.89s of the 786.38s of remaining time.
# (_dystack pid=258813) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.12%)
# (_dystack pid=258813) 	0.7349	 = Validation score   (roc_auc)
# (_dystack pid=258813) 	12.79s	 = Training   runtime
# (_dystack pid=258813) 	2.1s	 = Validation runtime
# (_dystack pid=258813) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 473.49s of the 771.98s of remaining time.
# (_dystack pid=258813) 	0.7251	 = Validation score   (roc_auc)
# (_dystack pid=258813) 	5.98s	 = Training   runtime
# (_dystack pid=258813) 	10.64s	 = Validation runtime
# (_dystack pid=258813) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 455.35s of the 753.84s of remaining time.
# (_dystack pid=258813) 	0.7258	 = Validation score   (roc_auc)
# (_dystack pid=258813) 	6.17s	 = Training   runtime
# (_dystack pid=258813) 	10.7s	 = Validation runtime
# (_dystack pid=258813) Fitting model: CatBoost_BAG_L1 ... Training model for up to 437.11s of the 735.60s of remaining time.
# (_dystack pid=258813) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (6.0 workers, per: cpus=1, gpus=0, memory=0.12%)
# (_dystack pid=258813) 	0.7351	 = Validation score   (roc_auc)
# (_dystack pid=258813) 	61.96s	 = Training   runtime
# (_dystack pid=258813) 	0.19s	 = Validation runtime
# (_dystack pid=258813) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 373.83s of the 672.32s of remaining time.
# (_dystack pid=258813) 	0.7245	 = Validation score   (roc_auc)
# (_dystack pid=258813) 	5.1s	 = Training   runtime
# (_dystack pid=258813) 	11.45s	 = Validation runtime
# (_dystack pid=258813) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 355.79s of the 654.28s of remaining time.
# (_dystack pid=258813) 	0.7246	 = Validation score   (roc_auc)
# (_dystack pid=258813) 	5.15s	 = Training   runtime
# (_dystack pid=258813) 	10.82s	 = Validation runtime
# (_dystack pid=258813) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 338.38s of the 636.88s of remaining time.
# (_dystack pid=258813) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (6.0 workers, per: cpus=1, gpus=0, memory=0.20%)
# (_dystack pid=258813) 	0.7326	 = Validation score   (roc_auc)
# (_dystack pid=258813) 	237.08s	 = Training   runtime
# (_dystack pid=258813) 	2.69s	 = Validation runtime
# (_dystack pid=258813) Fitting model: XGBoost_BAG_L1 ... Training model for up to 99.58s of the 398.07s of remaining time.
# (_dystack pid=258813) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (6.0 workers, per: cpus=1, gpus=0, memory=0.16%)
# (_dystack pid=258813) 	0.7348	 = Validation score   (roc_auc)
# (_dystack pid=258813) 	58.57s	 = Training   runtime
# (_dystack pid=258813) 	1.4s	 = Validation runtime
# (_dystack pid=258813) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 39.56s of the 338.05s of remaining time.
# (_dystack pid=258813) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (3 workers, per: cpus=2, gpus=0, memory=0.11%)
# (_ray_fit pid=267333) 	Ran out of time, stopping training early. (Stopping on epoch 2)
# (_ray_fit pid=267332) 	Ran out of time, stopping training early. (Stopping on epoch 2) [repeated 3x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_ray_fit pid=268155) 	Ran out of time, stopping training early. (Stopping on epoch 2) [repeated 3x across cluster]
# (_dystack pid=258813) 	0.7284	 = Validation score   (roc_auc)
# (_dystack pid=258813) 	35.45s	 = Training   runtime
# (_dystack pid=258813) 	1.0s	 = Validation runtime
# (_dystack pid=258813) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 2.40s of the 300.89s of remaining time.
# (_dystack pid=258813) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# (_ray_fit pid=268510) 	Ran out of time, early stopping on iteration 33. Best iteration is:
# (_ray_fit pid=268510) 	[33]	valid_set's binary_logloss: 0.511296
# (_dystack pid=258813) 	0.733	 = Validation score   (roc_auc)
# (_dystack pid=258813) 	5.42s	 = Training   runtime
# (_dystack pid=258813) 	0.62s	 = Validation runtime
# (_dystack pid=258813) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 293.72s of remaining time.
# (_dystack pid=258813) 	Ensemble Weights: {'CatBoost_BAG_L1': 0.4, 'LightGBM_BAG_L1': 0.2, 'XGBoost_BAG_L1': 0.2, 'NeuralNetFastAI_BAG_L1': 0.12, 'RandomForestGini_BAG_L1': 0.04, 'RandomForestEntr_BAG_L1': 0.04}
# (_dystack pid=258813) 	0.7356	 = Validation score   (roc_auc)
# (_dystack pid=258813) 	11.72s	 = Training   runtime
# (_dystack pid=258813) 	0.03s	 = Validation runtime
# (_dystack pid=258813) Fitting 108 L2 models, fit_strategy="sequential" ...
# (_dystack pid=258813) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 281.91s of the 281.84s of remaining time.
# (_ray_fit pid=269043) 	Ran out of time, early stopping on iteration 39. Best iteration is: [repeated 7x across cluster]
# (_ray_fit pid=269043) 	[39]	valid_set's binary_logloss: 0.507785 [repeated 7x across cluster]
# (_dystack pid=258813) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.15%)
# (_ray_fit pid=269268) [1000]	valid_set's binary_logloss: 0.488006
# (_ray_fit pid=269269) [1000]	valid_set's binary_logloss: 0.489515
# (_ray_fit pid=269730) [1000]	valid_set's binary_logloss: 0.488779
# (_ray_fit pid=269268) [2000]	valid_set's binary_logloss: 0.487584
# (_ray_fit pid=269730) [2000]	valid_set's binary_logloss: 0.488019
# (_ray_fit pid=269268) [3000]	valid_set's binary_logloss: 0.487216
# (_ray_fit pid=269730) [3000]	valid_set's binary_logloss: 0.487564
# (_ray_fit pid=269268) [4000]	valid_set's binary_logloss: 0.487107
# (_ray_fit pid=269730) [4000]	valid_set's binary_logloss: 0.487503
# (_ray_fit pid=269268) [5000]	valid_set's binary_logloss: 0.486819
# (_ray_fit pid=269730) [5000]	valid_set's binary_logloss: 0.487334
# (_ray_fit pid=269268) [6000]	valid_set's binary_logloss: 0.486821
# (_ray_fit pid=269730) [6000]	valid_set's binary_logloss: 0.48738
# (_ray_fit pid=269268) [7000]	valid_set's binary_logloss: 0.486815
# (_ray_fit pid=269730) [7000]	valid_set's binary_logloss: 0.487419
# (_dystack pid=258813) 	0.7378	 = Validation score   (roc_auc)
# (_dystack pid=258813) 	136.43s	 = Training   runtime
# (_dystack pid=258813) 	24.73s	 = Validation runtime
# (_dystack pid=258813) Fitting model: LightGBM_BAG_L2 ... Training model for up to 132.26s of the 132.19s of remaining time.
# (_dystack pid=258813) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.15%)
# (_dystack pid=258813) 	0.7354	 = Validation score   (roc_auc)
# (_dystack pid=258813) 	13.92s	 = Training   runtime
# (_dystack pid=258813) 	1.37s	 = Validation runtime
# (_dystack pid=258813) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 116.36s of the 116.30s of remaining time.
# (_dystack pid=258813) 	0.7436	 = Validation score   (roc_auc)
# (_dystack pid=258813) 	11.02s	 = Training   runtime
# (_dystack pid=258813) 	12.22s	 = Validation runtime
# (_dystack pid=258813) Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 91.70s of the 91.63s of remaining time.
# (_dystack pid=258813) 	0.7435	 = Validation score   (roc_auc)
# (_dystack pid=258813) 	13.97s	 = Training   runtime
# (_dystack pid=258813) 	12.49s	 = Validation runtime
# (_dystack pid=258813) Fitting model: CatBoost_BAG_L2 ... Training model for up to 63.85s of the 63.78s of remaining time.
# (_dystack pid=258813) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (6.0 workers, per: cpus=1, gpus=0, memory=0.16%)
# (_ray_fit pid=271714) 	Ran out of time, early stopping on iteration 386.
# (_ray_fit pid=271717) 	Ran out of time, early stopping on iteration 412. [repeated 3x across cluster]
# (_dystack pid=258813) 	0.7358	 = Validation score   (roc_auc)
# (_dystack pid=258813) 	47.56s	 = Training   runtime
# (_dystack pid=258813) 	0.19s	 = Validation runtime
# (_dystack pid=258813) Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 14.47s of the 14.41s of remaining time.
# (_ray_fit pid=272689) 	Ran out of time, early stopping on iteration 412.
# (_dystack pid=258813) 	Not enough time to generate out-of-fold predictions for model. Estimated time required was 64.03s compared to 13.18s of available time.
# (_dystack pid=258813) 	Time limit exceeded... Skipping ExtraTreesGini_BAG_L2.
# (_dystack pid=258813) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the 8.41s of remaining time.
# (_dystack pid=258813) 	Ensemble Weights: {'RandomForestGini_BAG_L2': 0.444, 'RandomForestEntr_BAG_L2': 0.444, 'LightGBMXT_BAG_L2': 0.111}
# (_dystack pid=258813) 	0.7457	 = Validation score   (roc_auc)
# (_dystack pid=258813) 	16.0s	 = Training   runtime
# (_dystack pid=258813) 	0.03s	 = Validation runtime
# (_dystack pid=258813) AutoGluon training complete, total runtime = 904.04s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 505.8 rows/s (28484 batch size)
# (_dystack pid=258813) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/home/najo/NAS/LGaimers6/Baseline/AutogluonModels/ag-20250220_060351/ds_sub_fit/sub_fit_ho")
# (_dystack pid=258813) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0       WeightedEnsemble_L2       0.738270   0.735551     roc_auc        7.931192      27.750146  394.280814                 0.003846                0.034382          11.720975            2       True         14
# 1           CatBoost_BAG_L1       0.738267   0.735102     roc_auc        0.408660       0.187890   61.962155                 0.408660                0.187890          61.962155            1       True          7
# 2    NeuralNetFastAI_BAG_L1       0.737914   0.732619     roc_auc        4.680146       2.685198  237.083316                 4.680146                2.685198         237.083316            1       True         10
# 3           LightGBM_BAG_L2       0.737800   0.735354     roc_auc       22.090089     140.112024  471.082523                 0.268847                1.372253          13.924432            2       True         16
# 4            XGBoost_BAG_L1       0.737684   0.734802     roc_auc        0.484990       1.402766   58.572294                 0.484990                1.402766          58.572294            1       True         11
# 5           CatBoost_BAG_L2       0.737661   0.735797     roc_auc       21.935946     138.926087  504.720675                 0.114704                0.186316          47.562584            2       True         19
# 6           LightGBM_BAG_L1       0.737085   0.734914     roc_auc        0.324042       2.098564   12.793950                 0.324042                2.098564          12.793950            1       True          4
# 7         LightGBMXT_BAG_L2       0.736521   0.737775     roc_auc       25.333321     163.473809  593.586843                 3.512079               24.734038         136.428752            2       True         15
# 8         LightGBMXT_BAG_L1       0.736338   0.733526     roc_auc        0.694036       4.752136   23.036706                 0.694036                4.752136          23.036706            1       True          3
# 9      LightGBMLarge_BAG_L1       0.736169   0.733034     roc_auc        0.129752       0.616827    5.416961                 0.129752                0.616827           5.416961            1       True         13
# 10      WeightedEnsemble_L3       0.735667   0.745721     roc_auc       27.383321     188.217214  634.583976                 0.003011                0.032840          16.003567            3       True         20
# 11  RandomForestEntr_BAG_L2       0.734882   0.743493     roc_auc       22.884927     151.225989  471.128348                 1.063685               12.486218          13.970257            2       True         18
# 12    NeuralNetTorch_BAG_L1       0.734568   0.728363     roc_auc        0.924902       0.998714   35.447930                 0.924902                0.998714          35.447930            1       True         12
# 13  RandomForestGini_BAG_L2       0.734040   0.743626     roc_auc       22.804546     150.964118  468.181400                 0.983304               12.224347          11.023309            2       True         17
# 14    ExtraTreesEntr_BAG_L1       0.729058   0.724650     roc_auc        1.183970      10.822263    5.149464                 1.183970               10.822263           5.149464            1       True          9
# 15  RandomForestEntr_BAG_L1       0.728251   0.725771     roc_auc        0.978104      10.701430    6.172886                 0.978104               10.701430           6.172886            1       True          6
# 16    ExtraTreesGini_BAG_L1       0.728168   0.724481     roc_auc        0.977467      11.453395    5.101879                 0.977467               11.453395           5.101879            1       True          8
# 17  RandomForestGini_BAG_L1       0.728124   0.725129     roc_auc        1.051405      10.639916    5.975239                 1.051405               10.639916           5.975239            1       True          5
# 18    KNeighborsUnif_BAG_L1       0.655558   0.653515     roc_auc        5.018894      41.243674    0.220767                 5.018894               41.243674           0.220767            1       True          1
# 19    KNeighborsDist_BAG_L1       0.636749   0.629605     roc_auc        4.964874      41.136997    0.224545                 4.964874               41.136997           0.224545            1       True          2
# 	0	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: True)
# 	938s	 = DyStack   runtime |	2662s	 = Remaining runtime
# Starting main fit with num_stack_levels=0.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=0)`
# Beginning AutoGluon training ... Time limit = 2662s
# AutoGluon will save models to "/home/najo/NAS/LGaimers6/Baseline/AutogluonModels/ag-20250220_060351"
# Train Data Rows:    256351
# Train Data Columns: 39
# Label Column:       임신 성공 여부
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    233506.01 MB
# 	Train Data (Original)  Memory Usage: 75.30 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 15 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 2): ['불임 원인 - 여성 요인', '난자 채취 경과일']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Unused Original Features (Count: 3): ['불임 원인 - 정자 면역학적 요인', '불임 원인 - 정자 형태', '난자 해동 경과일']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 3 | ['불임 원인 - 정자 면역학적 요인', '불임 원인 - 정자 형태', '난자 해동 경과일']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 33 | ['시술 시기 코드', '시술 당시 나이', '임신 시도 또는 마지막 임신 경과 연수', '특정 시술 유형', '단일 배아 이식 여부', ...]
# 		('int', [])   :  1 | ['cluster_group']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 21 | ['시술 시기 코드', '시술 당시 나이', '임신 시도 또는 마지막 임신 경과 연수', '특정 시술 유형', '단일 배아 이식 여부', ...]
# 		('int', [])       :  1 | ['cluster_group']
# 		('int', ['bool']) : 12 | ['남성 부 불임 원인', '여성 주 불임 원인', '여성 부 불임 원인', '부부 부 불임 원인', '불명확 불임 원인', ...]
# 	1.1s = Fit runtime
# 	34 features in original data used to generate 34 features in processed data.
# 	Train Data (Processed) Memory Usage: 44.98 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 1.32s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 110 L1 models, fit_strategy="sequential" ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 2660.89s of the 2660.88s of remaining time.
# 	0.654	 = Validation score   (roc_auc)
# 	0.24s	 = Training   runtime
# 	18.22s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 2642.07s of the 2642.06s of remaining time.
# 	0.632	 = Validation score   (roc_auc)
# 	0.27s	 = Training   runtime
# 	18.17s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2623.38s of the 2623.37s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# 	0.7339	 = Validation score   (roc_auc)
# 	23.32s	 = Training   runtime
# 	4.53s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2597.52s of the 2597.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# 	0.7353	 = Validation score   (roc_auc)
# 	13.89s	 = Training   runtime
# 	2.25s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 2581.64s of the 2581.63s of remaining time.
# 	0.7265	 = Validation score   (roc_auc)
# 	5.66s	 = Training   runtime
# 	12.01s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 2562.54s of the 2562.54s of remaining time.
# 	0.7271	 = Validation score   (roc_auc)
# 	5.89s	 = Training   runtime
# 	13.28s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2542.02s of the 2542.01s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (6.0 workers, per: cpus=1, gpus=0, memory=0.13%)
# 	0.7356	 = Validation score   (roc_auc)
# 	88.1s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 2452.23s of the 2452.22s of remaining time.
# 	0.7254	 = Validation score   (roc_auc)
# 	5.15s	 = Training   runtime
# 	12.57s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 2433.21s of the 2433.20s of remaining time.
# 	0.7261	 = Validation score   (roc_auc)
# 	5.36s	 = Training   runtime
# 	11.74s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2414.89s of the 2414.88s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (6.0 workers, per: cpus=1, gpus=0, memory=0.21%)
# 	0.7333	 = Validation score   (roc_auc)
# 	271.76s	 = Training   runtime
# 	2.63s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 2141.01s of the 2141.00s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (6.0 workers, per: cpus=1, gpus=0, memory=0.17%)
# 	0.7354	 = Validation score   (roc_auc)
# 	77.89s	 = Training   runtime
# 	1.85s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2061.26s of the 2061.25s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (3 workers, per: cpus=2, gpus=0, memory=0.12%)
# 	0.7333	 = Validation score   (roc_auc)
# 	895.98s	 = Training   runtime
# 	1.18s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1163.50s of the 1163.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# 	0.7347	 = Validation score   (roc_auc)
# 	18.81s	 = Training   runtime
# 	3.27s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 1142.54s of the 1142.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (6.0 workers, per: cpus=1, gpus=0, memory=0.13%)
# 	0.7355	 = Validation score   (roc_auc)
# 	63.64s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 1077.20s of the 1077.19s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (3 workers, per: cpus=2, gpus=0, memory=0.11%)
# 	0.7331	 = Validation score   (roc_auc)
# 	705.14s	 = Training   runtime
# 	1.3s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 370.23s of the 370.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# 	0.7357	 = Validation score   (roc_auc)
# 	49.06s	 = Training   runtime
# 	13.39s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 317.77s of the 317.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (6.0 workers, per: cpus=1, gpus=0, memory=0.21%)
# 	0.7282	 = Validation score   (roc_auc)
# 	246.07s	 = Training   runtime
# 	6.14s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 69.29s of the 69.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (6.0 workers, per: cpus=1, gpus=0, memory=0.14%)
# 	0.7352	 = Validation score   (roc_auc)
# 	56.37s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 11.19s of the 11.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.12%)
# 	0.7263	 = Validation score   (roc_auc)
# 	19.72s	 = Training   runtime
# 	3.32s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the -10.69s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.261, 'XGBoost_BAG_L1': 0.217, 'LightGBM_r131_BAG_L1': 0.174, 'NeuralNetTorch_BAG_L1': 0.13, 'NeuralNetTorch_r79_BAG_L1': 0.087, 'RandomForestGini_BAG_L1': 0.043, 'NeuralNetFastAI_BAG_L1': 0.043, 'CatBoost_r177_BAG_L1': 0.043}
# 	0.7362	 = Validation score   (roc_auc)
# 	19.06s	 = Training   runtime
# 	0.04s	 = Validation runtime
# AutoGluon training complete, total runtime = 2692.1s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 1440.6 rows/s (32044 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/home/najo/NAS/LGaimers6/Baseline/AutogluonModels/ag-20250220_060351")
#                           model  score_test  score_val eval_metric  \
# 0         KNeighborsDist_BAG_L1    0.966161   0.631998     roc_auc
# 1       RandomForestEntr_BAG_L1    0.908146   0.727089     roc_auc
# 2       RandomForestGini_BAG_L1    0.907762   0.726528     roc_auc
# 3         ExtraTreesGini_BAG_L1    0.889342   0.725403     roc_auc
# 4         ExtraTreesEntr_BAG_L1    0.888769   0.726096     roc_auc
# 5         KNeighborsUnif_BAG_L1    0.826922   0.653995     roc_auc
# 6          LightGBMLarge_BAG_L1    0.760407   0.734689     roc_auc
# 7           WeightedEnsemble_L2    0.755443   0.736240     roc_auc
# 8          LightGBM_r131_BAG_L1    0.747871   0.735677     roc_auc
# 9               CatBoost_BAG_L1    0.745702   0.735639     roc_auc
# 10               XGBoost_BAG_L1    0.745236   0.735389     roc_auc
# 11            LightGBMXT_BAG_L1    0.745208   0.733884     roc_auc
# 12         CatBoost_r177_BAG_L1    0.745196   0.735463     roc_auc
# 13           CatBoost_r9_BAG_L1    0.744283   0.735246     roc_auc
# 14              LightGBM_BAG_L1    0.744235   0.735334     roc_auc
# 15        NeuralNetTorch_BAG_L1    0.741352   0.733341     roc_auc
# 16       NeuralNetFastAI_BAG_L1    0.740519   0.733289     roc_auc
# 17    NeuralNetTorch_r79_BAG_L1    0.738365   0.733117     roc_auc
# 18  NeuralNetFastAI_r191_BAG_L1    0.734437   0.728151     roc_auc
# 19          LightGBM_r96_BAG_L1    0.727544   0.726318     roc_auc
#
#     pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  \
# 0        19.150973      18.174370     0.265800                19.150973
# 1         1.526156      13.278316     5.885077                 1.526156
# 2         1.584790      12.013081     5.663512                 1.584790
# 3         1.498913      12.568044     5.146178                 1.498913
# 4         1.544819      11.743327     5.361473                 1.544819
# 5        18.471337      18.223511     0.240502                18.471337
# 6         2.028799       3.271528    18.813151                 2.028799
# 7        44.824954      32.787617  2176.300529                 0.015257
# 8         6.305973      13.385923    49.063252                 6.305973
# 9         0.426372       0.192330    88.098321                 0.426372
# 10        3.114641       1.852394    77.894484                 3.114641
# 11        2.078299       4.528119    23.315606                 2.078299
# 12        0.321987       0.196942    63.641751                 0.321987
# 13        0.784747       0.323464    56.366308                 0.784747
# 14        1.387533       2.254165    13.891749                 1.387533
# 15        7.653381       1.176549   895.982015                 7.653381
# 16       15.979086       2.633977   271.756636                15.979086
# 17        9.423466       1.298748   705.143140                 9.423466
# 18       27.574509       6.138919   246.067934                27.574509
# 19        2.127806       3.315581    19.717000                 2.127806
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                18.174370           0.265800            1       True
# 1                13.278316           5.885077            1       True
# 2                12.013081           5.663512            1       True
# 3                12.568044           5.146178            1       True
# 4                11.743327           5.361473            1       True
# 5                18.223511           0.240502            1       True
# 6                 3.271528          18.813151            1       True
# 7                 0.037671          19.057418            2       True
# 8                13.385923          49.063252            1       True
# 9                 0.192330          88.098321            1       True
# 10                1.852394          77.894484            1       True
# 11                4.528119          23.315606            1       True
# 12                0.196942          63.641751            1       True
# 13                0.323464          56.366308            1       True
# 14                2.254165          13.891749            1       True
# 15                1.176549         895.982015            1       True
# 16                2.633977         271.756636            1       True
# 17                1.298748         705.143140            1       True
# 18                6.138919         246.067934            1       True
# 19                3.315581          19.717000            1       True
#
#     fit_order
# 0           2
# 1           6
# 2           5
# 3           8
# 4           9
# 5           1
# 6          13
# 7          20
# 8          16
# 9           7
# 10         11
# 11          3
# 12         14
# 13         18
# 14          4
# 15         12
# 16         10
# 17         15
# 18         17
# 19         19

# %%
results = predictor.fit_summary()
results
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                           model  score_val eval_metric  pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0           WeightedEnsemble_L2   0.736240     roc_auc      32.787617  2176.300529                0.037671          19.057418            2       True         20
# 1          LightGBM_r131_BAG_L1   0.735677     roc_auc      13.385923    49.063252               13.385923          49.063252            1       True         16
# 2               CatBoost_BAG_L1   0.735639     roc_auc       0.192330    88.098321                0.192330          88.098321            1       True          7
# 3          CatBoost_r177_BAG_L1   0.735463     roc_auc       0.196942    63.641751                0.196942          63.641751            1       True         14
# 4                XGBoost_BAG_L1   0.735389     roc_auc       1.852394    77.894484                1.852394          77.894484            1       True         11
# 5               LightGBM_BAG_L1   0.735334     roc_auc       2.254165    13.891749                2.254165          13.891749            1       True          4
# 6            CatBoost_r9_BAG_L1   0.735246     roc_auc       0.323464    56.366308                0.323464          56.366308            1       True         18
# 7          LightGBMLarge_BAG_L1   0.734689     roc_auc       3.271528    18.813151                3.271528          18.813151            1       True         13
# 8             LightGBMXT_BAG_L1   0.733884     roc_auc       4.528119    23.315606                4.528119          23.315606            1       True          3
# 9         NeuralNetTorch_BAG_L1   0.733341     roc_auc       1.176549   895.982015                1.176549         895.982015            1       True         12
# 10       NeuralNetFastAI_BAG_L1   0.733289     roc_auc       2.633977   271.756636                2.633977         271.756636            1       True         10
# 11    NeuralNetTorch_r79_BAG_L1   0.733117     roc_auc       1.298748   705.143140                1.298748         705.143140            1       True         15
# 12  NeuralNetFastAI_r191_BAG_L1   0.728151     roc_auc       6.138919   246.067934                6.138919         246.067934            1       True         17
# 13      RandomForestEntr_BAG_L1   0.727089     roc_auc      13.278316     5.885077               13.278316           5.885077            1       True          6
# 14      RandomForestGini_BAG_L1   0.726528     roc_auc      12.013081     5.663512               12.013081           5.663512            1       True          5
# 15          LightGBM_r96_BAG_L1   0.726318     roc_auc       3.315581    19.717000                3.315581          19.717000            1       True         19
# 16        ExtraTreesEntr_BAG_L1   0.726096     roc_auc      11.743327     5.361473               11.743327           5.361473            1       True          9
# 17        ExtraTreesGini_BAG_L1   0.725403     roc_auc      12.568044     5.146178               12.568044           5.146178            1       True          8
# 18        KNeighborsUnif_BAG_L1   0.653995     roc_auc      18.223511     0.240502               18.223511           0.240502            1       True          1
# 19        KNeighborsDist_BAG_L1   0.631998     roc_auc      18.174370     0.265800               18.174370           0.265800            1       True          2
# Number of models trained: 20
# Types of models trained:
# {'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_LGB', 'WeightedEnsembleModel', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_NNFastAiTabular'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])     : 21 | ['시술 시기 코드', '시술 당시 나이', '임신 시도 또는 마지막 임신 경과 연수', '특정 시술 유형', '단일 배아 이식 여부', ...]
# ('int', [])       :  1 | ['cluster_group']
# ('int', ['bool']) : 12 | ['남성 부 불임 원인', '여성 주 불임 원인', '여성 부 불임 원인', '부부 부 불임 원인', '불명확 불임 원인', ...]
# *** End of fit() summary ***
# /home/najo/.conda/envs/dip/lib/python3.10/site-packages/autogluon/core/utils/plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r131_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r191_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r9_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L1': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.6539950185089027,
#   'KNeighborsDist_BAG_L1': 0.6319978322374928,
#   'LightGBMXT_BAG_L1': 0.7338842239028476,
#   'LightGBM_BAG_L1': 0.7353335260679991,
#   'RandomForestGini_BAG_L1': 0.7265282338079424,
#   'RandomForestEntr_BAG_L1': 0.7270887774313248,
#   'CatBoost_BAG_L1': 0.7356392130695405,
#   'ExtraTreesGini_BAG_L1': 0.7254033320728701,
#   'ExtraTreesEntr_BAG_L1': 0.7260961777645089,
#   'NeuralNetFastAI_BAG_L1': 0.7332885460466083,
#   'XGBoost_BAG_L1': 0.7353892598878378,
#   'NeuralNetTorch_BAG_L1': 0.7333406923175594,
#   'LightGBMLarge_BAG_L1': 0.7346894627419607,
#   'CatBoost_r177_BAG_L1': 0.7354628110531082,
#   'NeuralNetTorch_r79_BAG_L1': 0.7331170949627984,
#   'LightGBM_r131_BAG_L1': 0.7356772199226207,
#   'NeuralNetFastAI_r191_BAG_L1': 0.7281511331930173,
#   'CatBoost_r9_BAG_L1': 0.7352459203836297,
#   'LightGBM_r96_BAG_L1': 0.7263180595525578,
#   'WeightedEnsemble_L2': 0.7362398642545234},
#  'model_best': 'WeightedEnsemble_L2',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'CatBoost_r177_BAG_L1': ['CatBoost_r177_BAG_L1'],
#   'NeuralNetTorch_r79_BAG_L1': ['NeuralNetTorch_r79_BAG_L1'],
#   'LightGBM_r131_BAG_L1': ['LightGBM_r131_BAG_L1'],
#   'NeuralNetFastAI_r191_BAG_L1': ['NeuralNetFastAI_r191_BAG_L1'],
#   'CatBoost_r9_BAG_L1': ['CatBoost_r9_BAG_L1'],
#   'LightGBM_r96_BAG_L1': ['LightGBM_r96_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.24050188064575195,
#   'KNeighborsDist_BAG_L1': 0.26580023765563965,
#   'LightGBMXT_BAG_L1': 23.315606355667114,
#   'LightGBM_BAG_L1': 13.891748905181885,
#   'RandomForestGini_BAG_L1': 5.6635119915008545,
#   'RandomForestEntr_BAG_L1': 5.885076999664307,
#   'CatBoost_BAG_L1': 88.09832096099854,
#   'ExtraTreesGini_BAG_L1': 5.146177530288696,
#   'ExtraTreesEntr_BAG_L1': 5.361473321914673,
#   'NeuralNetFastAI_BAG_L1': 271.75663566589355,
#   'XGBoost_BAG_L1': 77.89448380470276,
#   'NeuralNetTorch_BAG_L1': 895.9820153713226,
#   'LightGBMLarge_BAG_L1': 18.813150644302368,
#   'CatBoost_r177_BAG_L1': 63.64175081253052,
#   'NeuralNetTorch_r79_BAG_L1': 705.1431400775909,
#   'LightGBM_r131_BAG_L1': 49.063252210617065,
#   'NeuralNetFastAI_r191_BAG_L1': 246.06793355941772,
#   'CatBoost_r9_BAG_L1': 56.36630821228027,
#   'LightGBM_r96_BAG_L1': 19.716999530792236,
#   'WeightedEnsemble_L2': 19.05741786956787},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 18.223511219024658,
#   'KNeighborsDist_BAG_L1': 18.17436957359314,
#   'LightGBMXT_BAG_L1': 4.528119087219238,
#   'LightGBM_BAG_L1': 2.2541651725769043,
#   'RandomForestGini_BAG_L1': 12.013081073760986,
#   'RandomForestEntr_BAG_L1': 13.278316259384155,
#   'CatBoost_BAG_L1': 0.19232964515686035,
#   'ExtraTreesGini_BAG_L1': 12.568044424057007,
#   'ExtraTreesEntr_BAG_L1': 11.743327379226685,
#   'NeuralNetFastAI_BAG_L1': 2.633976697921753,
#   'XGBoost_BAG_L1': 1.8523943424224854,
#   'NeuralNetTorch_BAG_L1': 1.1765494346618652,
#   'LightGBMLarge_BAG_L1': 3.2715277671813965,
#   'CatBoost_r177_BAG_L1': 0.19694232940673828,
#   'NeuralNetTorch_r79_BAG_L1': 1.29874849319458,
#   'LightGBM_r131_BAG_L1': 13.385923385620117,
#   'NeuralNetFastAI_r191_BAG_L1': 6.138918876647949,
#   'CatBoost_r9_BAG_L1': 0.32346439361572266,
#   'LightGBM_r96_BAG_L1': 3.3155810832977295,
#   'WeightedEnsemble_L2': 0.03767132759094238},
#  'num_bag_folds': 8,
#  'max_stack_level': 2,
#  'num_classes': 2,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetTorch_r79_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r131_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r191_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'CatBoost_r9_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'LightGBM_r96_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True}},
#  'leaderboard':                           model  score_val eval_metric  pred_time_val  \
#  0           WeightedEnsemble_L2   0.736240     roc_auc      32.787617
#  1          LightGBM_r131_BAG_L1   0.735677     roc_auc      13.385923
#  2               CatBoost_BAG_L1   0.735639     roc_auc       0.192330
#  3          CatBoost_r177_BAG_L1   0.735463     roc_auc       0.196942
#  4                XGBoost_BAG_L1   0.735389     roc_auc       1.852394
#  5               LightGBM_BAG_L1   0.735334     roc_auc       2.254165
#  6            CatBoost_r9_BAG_L1   0.735246     roc_auc       0.323464
#  7          LightGBMLarge_BAG_L1   0.734689     roc_auc       3.271528
#  8             LightGBMXT_BAG_L1   0.733884     roc_auc       4.528119
#  9         NeuralNetTorch_BAG_L1   0.733341     roc_auc       1.176549
#  10       NeuralNetFastAI_BAG_L1   0.733289     roc_auc       2.633977
#  11    NeuralNetTorch_r79_BAG_L1   0.733117     roc_auc       1.298748
#  12  NeuralNetFastAI_r191_BAG_L1   0.728151     roc_auc       6.138919
#  13      RandomForestEntr_BAG_L1   0.727089     roc_auc      13.278316
#  14      RandomForestGini_BAG_L1   0.726528     roc_auc      12.013081
#  15          LightGBM_r96_BAG_L1   0.726318     roc_auc       3.315581
#  16        ExtraTreesEntr_BAG_L1   0.726096     roc_auc      11.743327
#  17        ExtraTreesGini_BAG_L1   0.725403     roc_auc      12.568044
#  18        KNeighborsUnif_BAG_L1   0.653995     roc_auc      18.223511
#  19        KNeighborsDist_BAG_L1   0.631998     roc_auc      18.174370
#
#         fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0   2176.300529                0.037671          19.057418            2
#  1     49.063252               13.385923          49.063252            1
#  2     88.098321                0.192330          88.098321            1
#  3     63.641751                0.196942          63.641751            1
#  4     77.894484                1.852394          77.894484            1
#  5     13.891749                2.254165          13.891749            1
#  6     56.366308                0.323464          56.366308            1
#  7     18.813151                3.271528          18.813151            1
#  8     23.315606                4.528119          23.315606            1
#  9    895.982015                1.176549         895.982015            1
#  10   271.756636                2.633977         271.756636            1
#  11   705.143140                1.298748         705.143140            1
#  12   246.067934                6.138919         246.067934            1
#  13     5.885077               13.278316           5.885077            1
#  14     5.663512               12.013081           5.663512            1
#  15    19.717000                3.315581          19.717000            1
#  16     5.361473               11.743327           5.361473            1
#  17     5.146178               12.568044           5.146178            1
#  18     0.240502               18.223511           0.240502            1
#  19     0.265800               18.174370           0.265800            1
#
#      can_infer  fit_order
#  0        True         20
#  1        True         16
#  2        True          7
#  3        True         14
#  4        True         11
#  5        True          4
#  6        True         18
#  7        True         13
#  8        True          3
#  9        True         12
#  10       True         10
#  11       True         15
#  12       True         17
#  13       True          6
#  14       True          5
#  15       True         19
#  16       True          9
#  17       True          8
#  18       True          1
#  19       True          2  }

# %%
L2_prediction = predictor.predict_proba(test, model='WeightedEnsemble_L2')
cat_prediction = predictor.predict_proba(test, model='LightGBM_r131_BAG_L1')
XGB_prediction = predictor.predict_proba(test, model='CatBoost_BAG_L1')
LGBM_prediction = predictor.predict_proba(test, model='CatBoost_r177_BAG_L1')

final_train_pred_proba = (
    0.45 * L2_prediction +
    0.45 * cat_prediction +
    0.05 * XGB_prediction +
    0.05 * LGBM_prediction
)

# %%
final_train_pred_proba.drop(columns=[0])
print(final_train_pred_proba.head(5))

# 제출 파일 생성
sample_submission = pd.read_csv('./data/sample_submission.csv')
sample_submission['probability'] = final_train_pred_proba[1]
sample_submission.to_csv('./submit/final_submit.csv', index=False)
print(sample_submission.head(5))
# Out:
#           0         1
# 0  0.998587  0.001413
# 1  0.997330  0.002670
# 2  0.846437  0.153563
# 3  0.876118  0.123882
# 4  0.469360  0.530640
#            ID  probability
# 0  TEST_00000     0.001413
# 1  TEST_00001     0.002670
# 2  TEST_00002     0.153563
# 3  TEST_00003     0.123882
# 4  TEST_00004     0.530640
